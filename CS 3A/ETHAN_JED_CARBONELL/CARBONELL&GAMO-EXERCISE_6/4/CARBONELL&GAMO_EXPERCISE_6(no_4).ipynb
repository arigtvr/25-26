# %% [markdown]
# # Muffin VS Chihuahua Classification using InceptionNet (InceptionV3)
#
#
# *   Kirk Henrich Gamo & Ethan Jed Carbonell
#
# ## NOTE: Open this project in **Google Colab** to test
# > https://colab.research.google.com/drive/1VmpF9TPfpcG7MbYHb0Qvk054kSBDsB9q?usp=sharing

# %% [markdown]
# # Setup & Data Loading
#
# > We prepared the Google Colab environment by installing necessary libraries like kagglehub and torch. We then located the "Muffin vs. Chihuahua" dataset. We concluded by performing a brief exploration to confirm the dataset's structure, check the distribution of images per class, and visualize a few samples to ensure everything was loaded correctly.

# %%
# !pip install -q kagglehub torch torchvision matplotlib seaborn

import os
import torch
import kagglehub
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from torchvision import datasets
from pathlib import Path

#Setup device
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
mounted_path = Path("/kaggle/input/muffin-vs-chihuahua-image-classification")
download_path = Path("muffin-vs-chihuahua-image-classification")
DATA_PATH = None

if mounted_path.exists():
    print(f"Dataset found at the pre-mounted path: {mounted_path}")
    DATA_PATH = mounted_path
else:
    try:
        kagglehub.dataset_download(
            "samuelcortinhas/muffin-vs-chihuahua-image-classification",
            path=download_path
        )
        DATA_PATH = download_path
    except Exception as e:
        print(f"An error occurred during download: {e}")

if DATA_PATH:
    print("\nInspecting directory structure:")
    # !ls -R {str(DATA_PATH)}
else:
    print("\nCould not locate or download the dataset.")
# Out:
# Dataset found at the pre-mounted path: /kaggle/input/muffin-vs-chihuahua-image-classification
#
# Inspecting directory structure:
# /kaggle/input/muffin-vs-chihuahua-image-classification:
# test  train
#
# /kaggle/input/muffin-vs-chihuahua-image-classification/test:
# chihuahua  muffin
#
# /kaggle/input/muffin-vs-chihuahua-image-classification/test/chihuahua:
# img_0_1071.jpg	img_0_90.jpg	img_1_668.jpg	img_2_712.jpg	img_3_80.jpg
# img_0_1074.jpg	img_0_930.jpg	img_1_682.jpg	img_2_722.jpg	img_3_819.jpg
# img_0_1082.jpg	img_0_935.jpg	img_1_685.jpg	img_2_731.jpg	img_3_824.jpg
# img_0_1087.jpg	img_0_939.jpg	img_1_68.jpg	img_2_733.jpg	img_3_836.jpg
# img_0_1107.jpg	img_0_947.jpg	img_1_691.jpg	img_2_734.jpg	img_3_839.jpg
# img_0_1110.jpg	img_0_94.jpg	img_1_708.jpg	img_2_735.jpg	img_3_843.jpg
# img_0_1112.jpg	img_0_951.jpg	img_1_712.jpg	img_2_747.jpg	img_3_854.jpg
# img_0_1117.jpg	img_0_960.jpg	img_1_722.jpg	img_2_752.jpg	img_3_856.jpg
# img_0_1122.jpg	img_0_964.jpg	img_1_731.jpg	img_2_763.jpg	img_3_886.jpg
# img_0_1133.jpg	img_0_988.jpg	img_1_732.jpg	img_2_765.jpg	img_3_889.jpg
# img_0_1139.jpg	img_0_996.jpg	img_1_747.jpg	img_2_779.jpg	img_3_900.jpg
# img_0_1150.jpg	img_1_1001.jpg	img_1_749.jpg	img_2_781.jpg	img_3_903.jpg
# img_0_1151.jpg	img_1_100.jpg	img_1_74.jpg	img_2_792.jpg	img_3_918.jpg
# img_0_1154.jpg	img_1_1014.jpg	img_1_750.jpg	img_2_801.jpg	img_3_922.jpg
# img_0_1159.jpg	img_1_1029.jpg	img_1_751.jpg	img_2_810.jpg	img_3_961.jpg
# img_0_1161.jpg	img_1_1031.jpg	img_1_765.jpg	img_2_811.jpg	img_3_968.jpg
# img_0_1169.jpg	img_1_1036.jpg	img_1_766.jpg	img_2_828.jpg	img_3_979.jpg
# img_0_1172.jpg	img_1_103.jpg	img_1_768.jpg	img_2_831.jpg	img_3_98.jpg
# img_0_1180.jpg	img_1_1044.jpg	img_1_76.jpg	img_2_832.jpg	img_3_990.jpg
# img_0_1191.jpg	img_1_1045.jpg	img_1_773.jpg	img_2_856.jpg	img_3_99.jpg
# img_0_1196.jpg	img_1_1059.jpg	img_1_776.jpg	img_2_859.jpg	img_3_9.jpg
# img_0_11.jpg	img_1_1062.jpg	img_1_803.jpg	img_2_85.jpg	img_4_1024.jpg
# img_0_1200.jpg	img_1_1079.jpg	img_1_816.jpg	img_2_867.jpg	img_4_1030.jpg
# img_0_1201.jpg	img_1_1094.jpg	img_1_821.jpg	img_2_878.jpg	img_4_1040.jpg
# img_0_1212.jpg	img_1_1096.jpg	img_1_824.jpg	img_2_888.jpg	img_4_129.jpg
# img_0_137.jpg	img_1_1104.jpg	img_1_832.jpg	img_2_900.jpg	img_4_131.jpg
# img_0_138.jpg	img_1_1114.jpg	img_1_842.jpg	img_2_904.jpg	img_4_136.jpg
# img_0_146.jpg	img_1_1130.jpg	img_1_859.jpg	img_2_928.jpg	img_4_146.jpg
# img_0_151.jpg	img_1_1143.jpg	img_1_864.jpg	img_2_92.jpg	img_4_156.jpg
# img_0_152.jpg	img_1_1152.jpg	img_1_878.jpg	img_2_951.jpg	img_4_159.jpg
# img_0_16.jpg	img_1_1154.jpg	img_1_883.jpg	img_2_960.jpg	img_4_163.jpg
# img_0_177.jpg	img_1_1160.jpg	img_1_885.jpg	img_2_969.jpg	img_4_164.jpg
# img_0_17.jpg	img_1_117.jpg	img_1_886.jpg	img_2_974.jpg	img_4_173.jpg
# img_0_184.jpg	img_1_1181.jpg	img_1_887.jpg	img_2_979.jpg	img_4_178.jpg
# img_0_18.jpg	img_1_1192.jpg	img_1_890.jpg	img_2_983.jpg	img_4_182.jpg
# img_0_203.jpg	img_1_1196.jpg	img_1_896.jpg	img_2_986.jpg	img_4_185.jpg
# img_0_229.jpg	img_1_1197.jpg	img_1_902.jpg	img_2_989.jpg	img_4_200.jpg
# img_0_22.jpg	img_1_1206.jpg	img_1_909.jpg	img_2_996.jpg	img_4_205.jpg
# img_0_235.jpg	img_1_1217.jpg	img_1_915.jpg	img_2_998.jpg	img_4_209.jpg
# img_0_24.jpg	img_1_122.jpg	img_1_918.jpg	img_3_1004.jpg	img_4_211.jpg
# img_0_274.jpg	img_1_1245.jpg	img_1_919.jpg	img_3_1021.jpg	img_4_214.jpg
# img_0_275.jpg	img_1_1248.jpg	img_1_945.jpg	img_3_1025.jpg	img_4_21.jpg
# img_0_290.jpg	img_1_1251.jpg	img_1_946.jpg	img_3_1043.jpg	img_4_226.jpg
# img_0_292.jpg	img_1_125.jpg	img_1_950.jpg	img_3_108.jpg	img_4_240.jpg
# img_0_295.jpg	img_1_1267.jpg	img_1_951.jpg	img_3_109.jpg	img_4_243.jpg
# img_0_298.jpg	img_1_1274.jpg	img_1_960.jpg	img_3_111.jpg	img_4_269.jpg
# img_0_301.jpg	img_1_1280.jpg	img_1_977.jpg	img_3_115.jpg	img_4_297.jpg
# img_0_302.jpg	img_1_1295.jpg	img_1_986.jpg	img_3_119.jpg	img_4_305.jpg
# img_0_30.jpg	img_1_130.jpg	img_1_992.jpg	img_3_129.jpg	img_4_308.jpg
# img_0_329.jpg	img_1_136.jpg	img_1_998.jpg	img_3_140.jpg	img_4_309.jpg
# img_0_337.jpg	img_1_144.jpg	img_1_999.jpg	img_3_155.jpg	img_4_31.jpg
# img_0_340.jpg	img_1_145.jpg	img_2_1008.jpg	img_3_163.jpg	img_4_320.jpg
# img_0_343.jpg	img_1_149.jpg	img_2_1010.jpg	img_3_186.jpg	img_4_327.jpg
# img_0_345.jpg	img_1_153.jpg	img_2_1017.jpg	img_3_191.jpg	img_4_333.jpg
# img_0_346.jpg	img_1_15.jpg	img_2_1019.jpg	img_3_201.jpg	img_4_335.jpg
# img_0_352.jpg	img_1_164.jpg	img_2_1025.jpg	img_3_232.jpg	img_4_341.jpg
# img_0_368.jpg	img_1_168.jpg	img_2_1032.jpg	img_3_233.jpg	img_4_345.jpg
# img_0_383.jpg	img_1_174.jpg	img_2_1039.jpg	img_3_243.jpg	img_4_351.jpg
# img_0_385.jpg	img_1_176.jpg	img_2_1043.jpg	img_3_249.jpg	img_4_356.jpg
# img_0_396.jpg	img_1_181.jpg	img_2_1044.jpg	img_3_258.jpg	img_4_357.jpg
# img_0_407.jpg	img_1_197.jpg	img_2_105.jpg	img_3_259.jpg	img_4_360.jpg
# img_0_40.jpg	img_1_198.jpg	img_2_1079.jpg	img_3_262.jpg	img_4_36.jpg
# img_0_410.jpg	img_1_206.jpg	img_2_1080.jpg	img_3_267.jpg	img_4_379.jpg
# img_0_414.jpg	img_1_208.jpg	img_2_109.jpg	img_3_275.jpg	img_4_394.jpg
# img_0_418.jpg	img_1_211.jpg	img_2_114.jpg	img_3_291.jpg	img_4_402.jpg
# img_0_436.jpg	img_1_215.jpg	img_2_125.jpg	img_3_295.jpg	img_4_416.jpg
# img_0_43.jpg	img_1_219.jpg	img_2_135.jpg	img_3_300.jpg	img_4_418.jpg
# img_0_448.jpg	img_1_21.jpg	img_2_139.jpg	img_3_303.jpg	img_4_466.jpg
# img_0_455.jpg	img_1_227.jpg	img_2_147.jpg	img_3_304.jpg	img_4_468.jpg
# img_0_468.jpg	img_1_233.jpg	img_2_159.jpg	img_3_311.jpg	img_4_476.jpg
# img_0_46.jpg	img_1_263.jpg	img_2_175.jpg	img_3_314.jpg	img_4_495.jpg
# img_0_470.jpg	img_1_273.jpg	img_2_198.jpg	img_3_320.jpg	img_4_512.jpg
# img_0_47.jpg	img_1_274.jpg	img_2_202.jpg	img_3_326.jpg	img_4_514.jpg
# img_0_485.jpg	img_1_275.jpg	img_2_206.jpg	img_3_331.jpg	img_4_522.jpg
# img_0_48.jpg	img_1_276.jpg	img_2_220.jpg	img_3_333.jpg	img_4_537.jpg
# img_0_490.jpg	img_1_282.jpg	img_2_222.jpg	img_3_345.jpg	img_4_53.jpg
# img_0_491.jpg	img_1_284.jpg	img_2_230.jpg	img_3_351.jpg	img_4_545.jpg
# img_0_493.jpg	img_1_302.jpg	img_2_239.jpg	img_3_36.jpg	img_4_54.jpg
# img_0_498.jpg	img_1_305.jpg	img_2_250.jpg	img_3_377.jpg	img_4_551.jpg
# img_0_50.jpg	img_1_307.jpg	img_2_259.jpg	img_3_379.jpg	img_4_553.jpg
# img_0_516.jpg	img_1_308.jpg	img_2_25.jpg	img_3_396.jpg	img_4_567.jpg
# img_0_524.jpg	img_1_317.jpg	img_2_267.jpg	img_3_400.jpg	img_4_568.jpg
# img_0_540.jpg	img_1_332.jpg	img_2_269.jpg	img_3_403.jpg	img_4_578.jpg
# img_0_562.jpg	img_1_342.jpg	img_2_285.jpg	img_3_411.jpg	img_4_592.jpg
# img_0_567.jpg	img_1_343.jpg	img_2_287.jpg	img_3_413.jpg	img_4_600.jpg
# img_0_571.jpg	img_1_345.jpg	img_2_299.jpg	img_3_418.jpg	img_4_601.jpg
# img_0_580.jpg	img_1_348.jpg	img_2_302.jpg	img_3_421.jpg	img_4_605.jpg
# img_0_590.jpg	img_1_350.jpg	img_2_310.jpg	img_3_437.jpg	img_4_618.jpg
# img_0_597.jpg	img_1_356.jpg	img_2_323.jpg	img_3_438.jpg	img_4_619.jpg
# img_0_5.jpg	img_1_369.jpg	img_2_347.jpg	img_3_439.jpg	img_4_625.jpg
# img_0_609.jpg	img_1_370.jpg	img_2_368.jpg	img_3_43.jpg	img_4_640.jpg
# img_0_60.jpg	img_1_374.jpg	img_2_3.jpg	img_3_458.jpg	img_4_645.jpg
# img_0_612.jpg	img_1_397.jpg	img_2_403.jpg	img_3_464.jpg	img_4_650.jpg
# img_0_618.jpg	img_1_398.jpg	img_2_404.jpg	img_3_493.jpg	img_4_665.jpg
# img_0_624.jpg	img_1_416.jpg	img_2_409.jpg	img_3_495.jpg	img_4_668.jpg
# img_0_627.jpg	img_1_422.jpg	img_2_40.jpg	img_3_497.jpg	img_4_679.jpg
# img_0_629.jpg	img_1_428.jpg	img_2_424.jpg	img_3_52.jpg	img_4_680.jpg
# img_0_651.jpg	img_1_433.jpg	img_2_429.jpg	img_3_536.jpg	img_4_684.jpg
# img_0_661.jpg	img_1_435.jpg	img_2_42.jpg	img_3_53.jpg	img_4_685.jpg
# img_0_667.jpg	img_1_443.jpg	img_2_443.jpg	img_3_552.jpg	img_4_689.jpg
# img_0_682.jpg	img_1_44.jpg	img_2_455.jpg	img_3_559.jpg	img_4_69.jpg
# img_0_684.jpg	img_1_477.jpg	img_2_457.jpg	img_3_560.jpg	img_4_700.jpg
# img_0_691.jpg	img_1_478.jpg	img_2_462.jpg	img_3_569.jpg	img_4_704.jpg
# img_0_711.jpg	img_1_480.jpg	img_2_486.jpg	img_3_600.jpg	img_4_71.jpg
# img_0_712.jpg	img_1_494.jpg	img_2_496.jpg	img_3_614.jpg	img_4_729.jpg
# img_0_72.jpg	img_1_498.jpg	img_2_4.jpg	img_3_615.jpg	img_4_732.jpg
# img_0_731.jpg	img_1_504.jpg	img_2_504.jpg	img_3_617.jpg	img_4_735.jpg
# img_0_735.jpg	img_1_505.jpg	img_2_506.jpg	img_3_64.jpg	img_4_745.jpg
# img_0_742.jpg	img_1_528.jpg	img_2_507.jpg	img_3_653.jpg	img_4_75.jpg
# img_0_756.jpg	img_1_535.jpg	img_2_511.jpg	img_3_654.jpg	img_4_778.jpg
# img_0_774.jpg	img_1_538.jpg	img_2_51.jpg	img_3_660.jpg	img_4_789.jpg
# img_0_800.jpg	img_1_544.jpg	img_2_524.jpg	img_3_661.jpg	img_4_799.jpg
# img_0_805.jpg	img_1_548.jpg	img_2_534.jpg	img_3_664.jpg	img_4_809.jpg
# img_0_808.jpg	img_1_551.jpg	img_2_54.jpg	img_3_674.jpg	img_4_813.jpg
# img_0_814.jpg	img_1_565.jpg	img_2_561.jpg	img_3_68.jpg	img_4_819.jpg
# img_0_819.jpg	img_1_567.jpg	img_2_567.jpg	img_3_6.jpg	img_4_839.jpg
# img_0_826.jpg	img_1_57.jpg	img_2_588.jpg	img_3_700.jpg	img_4_854.jpg
# img_0_842.jpg	img_1_583.jpg	img_2_594.jpg	img_3_704.jpg	img_4_860.jpg
# img_0_848.jpg	img_1_587.jpg	img_2_625.jpg	img_3_720.jpg	img_4_874.jpg
# img_0_857.jpg	img_1_589.jpg	img_2_62.jpg	img_3_768.jpg	img_4_882.jpg
# img_0_866.jpg	img_1_593.jpg	img_2_631.jpg	img_3_777.jpg	img_4_894.jpg
# img_0_871.jpg	img_1_595.jpg	img_2_655.jpg	img_3_778.jpg	img_4_916.jpg
# img_0_881.jpg	img_1_602.jpg	img_2_65.jpg	img_3_77.jpg	img_4_922.jpg
# img_0_896.jpg	img_1_614.jpg	img_2_668.jpg	img_3_789.jpg	img_4_925.jpg
# img_0_8.jpg	img_1_619.jpg	img_2_66.jpg	img_3_78.jpg	img_4_929.jpg
# img_0_901.jpg	img_1_623.jpg	img_2_677.jpg	img_3_794.jpg	img_4_954.jpg
# img_0_905.jpg	img_1_636.jpg	img_2_702.jpg	img_3_798.jpg	img_4_96.jpg
# img_0_907.jpg	img_1_654.jpg	img_2_708.jpg	img_3_806.jpg	img_4_971.jpg
#
# /kaggle/input/muffin-vs-chihuahua-image-classification/test/muffin:
# img_0_0.jpg	img_1_175.jpg	img_2_159.jpg	img_3_1080.jpg	img_4_1155.jpg
# img_0_1000.jpg	img_1_196.jpg	img_2_175.jpg	img_3_1083.jpg	img_4_1173.jpg
# img_0_1037.jpg	img_1_1.jpg	img_2_17.jpg	img_3_1100.jpg	img_4_1174.jpg
# img_0_1050.jpg	img_1_208.jpg	img_2_181.jpg	img_3_1103.jpg	img_4_1184.jpg
# img_0_1051.jpg	img_1_210.jpg	img_2_187.jpg	img_3_1105.jpg	img_4_118.jpg
# img_0_105.jpg	img_1_226.jpg	img_2_1.jpg	img_3_1111.jpg	img_4_127.jpg
# img_0_1061.jpg	img_1_22.jpg	img_2_211.jpg	img_3_1125.jpg	img_4_129.jpg
# img_0_1063.jpg	img_1_239.jpg	img_2_217.jpg	img_3_112.jpg	img_4_16.jpg
# img_0_10.jpg	img_1_244.jpg	img_2_225.jpg	img_3_1147.jpg	img_4_179.jpg
# img_0_1102.jpg	img_1_247.jpg	img_2_22.jpg	img_3_1156.jpg	img_4_17.jpg
# img_0_1113.jpg	img_1_261.jpg	img_2_234.jpg	img_3_1159.jpg	img_4_194.jpg
# img_0_1114.jpg	img_1_272.jpg	img_2_252.jpg	img_3_1160.jpg	img_4_1.jpg
# img_0_1121.jpg	img_1_274.jpg	img_2_261.jpg	img_3_1172.jpg	img_4_204.jpg
# img_0_1123.jpg	img_1_280.jpg	img_2_26.jpg	img_3_1176.jpg	img_4_207.jpg
# img_0_187.jpg	img_1_284.jpg	img_2_278.jpg	img_3_1182.jpg	img_4_211.jpg
# img_0_189.jpg	img_1_287.jpg	img_2_280.jpg	img_3_1194.jpg	img_4_227.jpg
# img_0_196.jpg	img_1_32.jpg	img_2_29.jpg	img_3_1199.jpg	img_4_22.jpg
# img_0_222.jpg	img_1_330.jpg	img_2_302.jpg	img_3_1237.jpg	img_4_233.jpg
# img_0_228.jpg	img_1_355.jpg	img_2_305.jpg	img_3_1240.jpg	img_4_239.jpg
# img_0_25.jpg	img_1_361.jpg	img_2_307.jpg	img_3_1242.jpg	img_4_23.jpg
# img_0_262.jpg	img_1_376.jpg	img_2_314.jpg	img_3_1252.jpg	img_4_249.jpg
# img_0_306.jpg	img_1_379.jpg	img_2_328.jpg	img_3_125.jpg	img_4_24.jpg
# img_0_314.jpg	img_1_413.jpg	img_2_329.jpg	img_3_1266.jpg	img_4_266.jpg
# img_0_317.jpg	img_1_431.jpg	img_2_338.jpg	img_3_1270.jpg	img_4_26.jpg
# img_0_31.jpg	img_1_435.jpg	img_2_342.jpg	img_3_1286.jpg	img_4_325.jpg
# img_0_32.jpg	img_1_451.jpg	img_2_344.jpg	img_3_1293.jpg	img_4_348.jpg
# img_0_333.jpg	img_1_459.jpg	img_2_346.jpg	img_3_1316.jpg	img_4_354.jpg
# img_0_357.jpg	img_1_45.jpg	img_2_348.jpg	img_3_135.jpg	img_4_377.jpg
# img_0_35.jpg	img_1_469.jpg	img_2_356.jpg	img_3_166.jpg	img_4_387.jpg
# img_0_361.jpg	img_1_477.jpg	img_2_391.jpg	img_3_188.jpg	img_4_388.jpg
# img_0_363.jpg	img_1_482.jpg	img_2_399.jpg	img_3_212.jpg	img_4_408.jpg
# img_0_366.jpg	img_1_508.jpg	img_2_41.jpg	img_3_239.jpg	img_4_418.jpg
# img_0_376.jpg	img_1_515.jpg	img_2_427.jpg	img_3_276.jpg	img_4_419.jpg
# img_0_395.jpg	img_1_516.jpg	img_2_458.jpg	img_3_287.jpg	img_4_422.jpg
# img_0_3.jpg	img_1_524.jpg	img_2_461.jpg	img_3_28.jpg	img_4_424.jpg
# img_0_403.jpg	img_1_526.jpg	img_2_479.jpg	img_3_315.jpg	img_4_42.jpg
# img_0_408.jpg	img_1_530.jpg	img_2_481.jpg	img_3_320.jpg	img_4_430.jpg
# img_0_416.jpg	img_1_537.jpg	img_2_482.jpg	img_3_327.jpg	img_4_435.jpg
# img_0_423.jpg	img_1_543.jpg	img_2_484.jpg	img_3_338.jpg	img_4_441.jpg
# img_0_431.jpg	img_1_544.jpg	img_2_496.jpg	img_3_342.jpg	img_4_464.jpg
# img_0_432.jpg	img_1_545.jpg	img_2_499.jpg	img_3_349.jpg	img_4_475.jpg
# img_0_440.jpg	img_1_547.jpg	img_2_500.jpg	img_3_34.jpg	img_4_48.jpg
# img_0_504.jpg	img_1_572.jpg	img_2_508.jpg	img_3_373.jpg	img_4_496.jpg
# img_0_50.jpg	img_1_581.jpg	img_2_523.jpg	img_3_381.jpg	img_4_508.jpg
# img_0_512.jpg	img_1_582.jpg	img_2_527.jpg	img_3_383.jpg	img_4_510.jpg
# img_0_528.jpg	img_1_584.jpg	img_2_535.jpg	img_3_385.jpg	img_4_511.jpg
# img_0_53.jpg	img_1_585.jpg	img_2_539.jpg	img_3_409.jpg	img_4_520.jpg
# img_0_552.jpg	img_1_596.jpg	img_2_542.jpg	img_3_419.jpg	img_4_543.jpg
# img_0_569.jpg	img_1_597.jpg	img_2_577.jpg	img_3_431.jpg	img_4_554.jpg
# img_0_570.jpg	img_1_60.jpg	img_2_587.jpg	img_3_447.jpg	img_4_556.jpg
# img_0_591.jpg	img_1_638.jpg	img_2_613.jpg	img_3_449.jpg	img_4_562.jpg
# img_0_599.jpg	img_1_640.jpg	img_2_614.jpg	img_3_461.jpg	img_4_578.jpg
# img_0_602.jpg	img_1_645.jpg	img_2_61.jpg	img_3_462.jpg	img_4_583.jpg
# img_0_605.jpg	img_1_648.jpg	img_2_627.jpg	img_3_474.jpg	img_4_593.jpg
# img_0_606.jpg	img_1_665.jpg	img_2_630.jpg	img_3_50.jpg	img_4_606.jpg
# img_0_622.jpg	img_1_674.jpg	img_2_641.jpg	img_3_511.jpg	img_4_608.jpg
# img_0_629.jpg	img_1_694.jpg	img_2_644.jpg	img_3_545.jpg	img_4_627.jpg
# img_0_631.jpg	img_1_698.jpg	img_2_645.jpg	img_3_554.jpg	img_4_639.jpg
# img_0_666.jpg	img_1_708.jpg	img_2_668.jpg	img_3_570.jpg	img_4_642.jpg
# img_0_67.jpg	img_1_715.jpg	img_2_671.jpg	img_3_59.jpg	img_4_64.jpg
# img_0_695.jpg	img_1_723.jpg	img_2_681.jpg	img_3_613.jpg	img_4_660.jpg
# img_0_706.jpg	img_1_734.jpg	img_2_689.jpg	img_3_646.jpg	img_4_661.jpg
# img_0_726.jpg	img_1_738.jpg	img_2_709.jpg	img_3_658.jpg	img_4_662.jpg
# img_0_73.jpg	img_1_754.jpg	img_2_721.jpg	img_3_664.jpg	img_4_66.jpg
# img_0_750.jpg	img_1_755.jpg	img_2_735.jpg	img_3_685.jpg	img_4_675.jpg
# img_0_756.jpg	img_1_770.jpg	img_2_73.jpg	img_3_711.jpg	img_4_676.jpg
# img_0_757.jpg	img_1_783.jpg	img_2_752.jpg	img_3_71.jpg	img_4_697.jpg
# img_0_766.jpg	img_1_792.jpg	img_2_757.jpg	img_3_722.jpg	img_4_704.jpg
# img_0_774.jpg	img_1_796.jpg	img_2_762.jpg	img_3_747.jpg	img_4_713.jpg
# img_0_801.jpg	img_1_798.jpg	img_2_767.jpg	img_3_749.jpg	img_4_716.jpg
# img_0_803.jpg	img_1_802.jpg	img_2_784.jpg	img_3_756.jpg	img_4_71.jpg
# img_0_807.jpg	img_1_807.jpg	img_2_78.jpg	img_3_757.jpg	img_4_733.jpg
# img_0_821.jpg	img_1_816.jpg	img_2_799.jpg	img_3_762.jpg	img_4_746.jpg
# img_0_822.jpg	img_1_831.jpg	img_2_810.jpg	img_3_763.jpg	img_4_748.jpg
# img_0_827.jpg	img_1_849.jpg	img_2_819.jpg	img_3_799.jpg	img_4_751.jpg
# img_0_831.jpg	img_1_854.jpg	img_2_821.jpg	img_3_801.jpg	img_4_752.jpg
# img_0_833.jpg	img_1_865.jpg	img_2_824.jpg	img_3_80.jpg	img_4_767.jpg
# img_0_835.jpg	img_1_872.jpg	img_2_827.jpg	img_3_819.jpg	img_4_776.jpg
# img_0_842.jpg	img_1_881.jpg	img_2_82.jpg	img_3_830.jpg	img_4_778.jpg
# img_0_849.jpg	img_1_895.jpg	img_2_838.jpg	img_3_835.jpg	img_4_782.jpg
# img_0_863.jpg	img_1_903.jpg	img_2_857.jpg	img_3_840.jpg	img_4_788.jpg
# img_0_869.jpg	img_1_907.jpg	img_2_863.jpg	img_3_841.jpg	img_4_789.jpg
# img_0_871.jpg	img_1_908.jpg	img_2_869.jpg	img_3_854.jpg	img_4_791.jpg
# img_0_872.jpg	img_1_914.jpg	img_2_877.jpg	img_3_864.jpg	img_4_826.jpg
# img_0_924.jpg	img_1_920.jpg	img_2_883.jpg	img_3_868.jpg	img_4_82.jpg
# img_0_942.jpg	img_1_92.jpg	img_2_887.jpg	img_3_873.jpg	img_4_832.jpg
# img_0_950.jpg	img_1_953.jpg	img_2_8.jpg	img_3_879.jpg	img_4_848.jpg
# img_0_978.jpg	img_1_976.jpg	img_2_910.jpg	img_3_903.jpg	img_4_849.jpg
# img_0_994.jpg	img_1_986.jpg	img_2_923.jpg	img_3_909.jpg	img_4_858.jpg
# img_0_995.jpg	img_2_1005.jpg	img_2_930.jpg	img_3_914.jpg	img_4_859.jpg
# img_1_1002.jpg	img_2_1008.jpg	img_2_932.jpg	img_3_91.jpg	img_4_864.jpg
# img_1_1005.jpg	img_2_1019.jpg	img_2_93.jpg	img_3_92.jpg	img_4_880.jpg
# img_1_1008.jpg	img_2_1023.jpg	img_2_951.jpg	img_3_934.jpg	img_4_896.jpg
# img_1_1009.jpg	img_2_1027.jpg	img_2_955.jpg	img_3_979.jpg	img_4_900.jpg
# img_1_1013.jpg	img_2_1030.jpg	img_2_956.jpg	img_3_985.jpg	img_4_901.jpg
# img_1_1019.jpg	img_2_1044.jpg	img_2_963.jpg	img_4_1016.jpg	img_4_93.jpg
# img_1_1041.jpg	img_2_1060.jpg	img_2_968.jpg	img_4_1017.jpg	img_4_940.jpg
# img_1_111.jpg	img_2_1064.jpg	img_2_971.jpg	img_4_1019.jpg	img_4_948.jpg
# img_1_123.jpg	img_2_1066.jpg	img_2_982.jpg	img_4_1050.jpg	img_4_956.jpg
# img_1_125.jpg	img_2_1069.jpg	img_2_987.jpg	img_4_1055.jpg	img_4_960.jpg
# img_1_132.jpg	img_2_1082.jpg	img_2_990.jpg	img_4_1064.jpg	img_4_971.jpg
# img_1_134.jpg	img_2_1094.jpg	img_2_997.jpg	img_4_1074.jpg	img_4_972.jpg
# img_1_137.jpg	img_2_1100.jpg	img_3_1011.jpg	img_4_1094.jpg	img_4_978.jpg
# img_1_139.jpg	img_2_1115.jpg	img_3_1013.jpg	img_4_1096.jpg	img_4_979.jpg
# img_1_141.jpg	img_2_1118.jpg	img_3_1028.jpg	img_4_1109.jpg	img_4_989.jpg
# img_1_144.jpg	img_2_116.jpg	img_3_1035.jpg	img_4_1119.jpg	img_4_991.jpg
# img_1_152.jpg	img_2_134.jpg	img_3_1048.jpg	img_4_1126.jpg	img_4_996.jpg
# img_1_159.jpg	img_2_138.jpg	img_3_1052.jpg	img_4_1131.jpg	img_4_997.jpg
# img_1_15.jpg	img_2_144.jpg	img_3_1068.jpg	img_4_1154.jpg
#
# /kaggle/input/muffin-vs-chihuahua-image-classification/train:
# chihuahua  muffin
#
# /kaggle/input/muffin-vs-chihuahua-image-classification/train/chihuahua:
# img_0_0.jpg	img_0_906.jpg	img_1_740.jpg	img_2_862.jpg	img_3_950.jpg
# img_0_1003.jpg	img_0_909.jpg	img_1_741.jpg	img_2_863.jpg	img_3_953.jpg
# img_0_1004.jpg	img_0_912.jpg	img_1_743.jpg	img_2_864.jpg	img_3_954.jpg
# img_0_100.jpg	img_0_914.jpg	img_1_744.jpg	img_2_865.jpg	img_3_955.jpg
# img_0_1010.jpg	img_0_916.jpg	img_1_746.jpg	img_2_869.jpg	img_3_957.jpg
# img_0_1012.jpg	img_0_917.jpg	img_1_748.jpg	img_2_86.jpg	img_3_958.jpg
# img_0_1015.jpg	img_0_918.jpg	img_1_756.jpg	img_2_870.jpg	img_3_959.jpg
# img_0_1016.jpg	img_0_919.jpg	img_1_758.jpg	img_2_872.jpg	img_3_962.jpg
# img_0_1017.jpg	img_0_920.jpg	img_1_75.jpg	img_2_876.jpg	img_3_963.jpg
# img_0_1018.jpg	img_0_921.jpg	img_1_761.jpg	img_2_877.jpg	img_3_964.jpg
# img_0_1019.jpg	img_0_923.jpg	img_1_762.jpg	img_2_881.jpg	img_3_965.jpg
# img_0_101.jpg	img_0_924.jpg	img_1_772.jpg	img_2_884.jpg	img_3_970.jpg
# img_0_1020.jpg	img_0_926.jpg	img_1_77.jpg	img_2_886.jpg	img_3_971.jpg
# img_0_1021.jpg	img_0_928.jpg	img_1_781.jpg	img_2_887.jpg	img_3_972.jpg
# img_0_1022.jpg	img_0_929.jpg	img_1_783.jpg	img_2_88.jpg	img_3_973.jpg
# img_0_1025.jpg	img_0_934.jpg	img_1_784.jpg	img_2_890.jpg	img_3_975.jpg
# img_0_1026.jpg	img_0_937.jpg	img_1_787.jpg	img_2_892.jpg	img_3_976.jpg
# img_0_102.jpg	img_0_93.jpg	img_1_788.jpg	img_2_893.jpg	img_3_977.jpg
# img_0_1030.jpg	img_0_940.jpg	img_1_791.jpg	img_2_894.jpg	img_3_978.jpg
# img_0_1034.jpg	img_0_943.jpg	img_1_793.jpg	img_2_895.jpg	img_3_97.jpg
# img_0_1035.jpg	img_0_945.jpg	img_1_796.jpg	img_2_896.jpg	img_3_980.jpg
# img_0_1037.jpg	img_0_946.jpg	img_1_798.jpg	img_2_898.jpg	img_3_981.jpg
# img_0_1040.jpg	img_0_948.jpg	img_1_7.jpg	img_2_899.jpg	img_3_983.jpg
# img_0_1043.jpg	img_0_949.jpg	img_1_801.jpg	img_2_8.jpg	img_3_985.jpg
# img_0_1044.jpg	img_0_950.jpg	img_1_802.jpg	img_2_901.jpg	img_3_987.jpg
# img_0_1045.jpg	img_0_953.jpg	img_1_805.jpg	img_2_905.jpg	img_3_988.jpg
# img_0_1048.jpg	img_0_955.jpg	img_1_808.jpg	img_2_906.jpg	img_3_989.jpg
# img_0_1050.jpg	img_0_956.jpg	img_1_80.jpg	img_2_907.jpg	img_3_993.jpg
# img_0_1051.jpg	img_0_959.jpg	img_1_815.jpg	img_2_909.jpg	img_3_994.jpg
# img_0_1053.jpg	img_0_961.jpg	img_1_817.jpg	img_2_90.jpg	img_3_995.jpg
# img_0_1058.jpg	img_0_966.jpg	img_1_819.jpg	img_2_911.jpg	img_3_998.jpg
# img_0_1059.jpg	img_0_967.jpg	img_1_823.jpg	img_2_918.jpg	img_3_999.jpg
# img_0_1062.jpg	img_0_968.jpg	img_1_825.jpg	img_2_919.jpg	img_4_1000.jpg
# img_0_1064.jpg	img_0_969.jpg	img_1_826.jpg	img_2_920.jpg	img_4_1003.jpg
# img_0_1065.jpg	img_0_970.jpg	img_1_827.jpg	img_2_925.jpg	img_4_1004.jpg
# img_0_1069.jpg	img_0_971.jpg	img_1_828.jpg	img_2_926.jpg	img_4_1005.jpg
# img_0_106.jpg	img_0_973.jpg	img_1_830.jpg	img_2_931.jpg	img_4_1006.jpg
# img_0_1070.jpg	img_0_974.jpg	img_1_831.jpg	img_2_934.jpg	img_4_1007.jpg
# img_0_1073.jpg	img_0_975.jpg	img_1_833.jpg	img_2_936.jpg	img_4_1009.jpg
# img_0_1078.jpg	img_0_979.jpg	img_1_836.jpg	img_2_937.jpg	img_4_1010.jpg
# img_0_1079.jpg	img_0_981.jpg	img_1_837.jpg	img_2_940.jpg	img_4_1012.jpg
# img_0_1083.jpg	img_0_984.jpg	img_1_839.jpg	img_2_942.jpg	img_4_1013.jpg
# img_0_1084.jpg	img_0_985.jpg	img_1_83.jpg	img_2_943.jpg	img_4_1015.jpg
# img_0_1089.jpg	img_0_987.jpg	img_1_840.jpg	img_2_944.jpg	img_4_1016.jpg
# img_0_1093.jpg	img_0_98.jpg	img_1_841.jpg	img_2_949.jpg	img_4_101.jpg
# img_0_1095.jpg	img_0_990.jpg	img_1_845.jpg	img_2_94.jpg	img_4_1022.jpg
# img_0_1097.jpg	img_0_991.jpg	img_1_848.jpg	img_2_950.jpg	img_4_1023.jpg
# img_0_1098.jpg	img_0_992.jpg	img_1_84.jpg	img_2_952.jpg	img_4_1025.jpg
# img_0_1099.jpg	img_0_993.jpg	img_1_857.jpg	img_2_954.jpg	img_4_1026.jpg
# img_0_109.jpg	img_0_997.jpg	img_1_861.jpg	img_2_957.jpg	img_4_102.jpg
# img_0_10.jpg	img_0_999.jpg	img_1_862.jpg	img_2_95.jpg	img_4_1036.jpg
# img_0_1100.jpg	img_1_1002.jpg	img_1_869.jpg	img_2_961.jpg	img_4_1038.jpg
# img_0_1102.jpg	img_1_1003.jpg	img_1_870.jpg	img_2_964.jpg	img_4_103.jpg
# img_0_1103.jpg	img_1_1004.jpg	img_1_873.jpg	img_2_965.jpg	img_4_1042.jpg
# img_0_1111.jpg	img_1_1005.jpg	img_1_874.jpg	img_2_966.jpg	img_4_104.jpg
# img_0_1113.jpg	img_1_1006.jpg	img_1_879.jpg	img_2_968.jpg	img_4_105.jpg
# img_0_1114.jpg	img_1_1007.jpg	img_1_87.jpg	img_2_970.jpg	img_4_108.jpg
# img_0_1116.jpg	img_1_1009.jpg	img_1_89.jpg	img_2_972.jpg	img_4_110.jpg
# img_0_1118.jpg	img_1_1010.jpg	img_1_8.jpg	img_2_973.jpg	img_4_112.jpg
# img_0_1119.jpg	img_1_1011.jpg	img_1_900.jpg	img_2_975.jpg	img_4_113.jpg
# img_0_1120.jpg	img_1_1012.jpg	img_1_903.jpg	img_2_976.jpg	img_4_114.jpg
# img_0_1121.jpg	img_1_1015.jpg	img_1_905.jpg	img_2_977.jpg	img_4_115.jpg
# img_0_1123.jpg	img_1_1016.jpg	img_1_906.jpg	img_2_97.jpg	img_4_116.jpg
# img_0_1124.jpg	img_1_1017.jpg	img_1_907.jpg	img_2_981.jpg	img_4_11.jpg
# img_0_1126.jpg	img_1_1018.jpg	img_1_908.jpg	img_2_984.jpg	img_4_121.jpg
# img_0_1127.jpg	img_1_1020.jpg	img_1_90.jpg	img_2_987.jpg	img_4_122.jpg
# img_0_1129.jpg	img_1_1021.jpg	img_1_911.jpg	img_2_990.jpg	img_4_124.jpg
# img_0_112.jpg	img_1_1022.jpg	img_1_913.jpg	img_2_991.jpg	img_4_12.jpg
# img_0_1130.jpg	img_1_1023.jpg	img_1_916.jpg	img_2_992.jpg	img_4_130.jpg
# img_0_1135.jpg	img_1_1024.jpg	img_1_91.jpg	img_2_994.jpg	img_4_132.jpg
# img_0_1136.jpg	img_1_1025.jpg	img_1_920.jpg	img_2_999.jpg	img_4_133.jpg
# img_0_1140.jpg	img_1_1026.jpg	img_1_924.jpg	img_2_9.jpg	img_4_137.jpg
# img_0_1143.jpg	img_1_1027.jpg	img_1_930.jpg	img_3_0.jpg	img_4_138.jpg
# img_0_1144.jpg	img_1_1028.jpg	img_1_931.jpg	img_3_1000.jpg	img_4_13.jpg
# img_0_1146.jpg	img_1_1032.jpg	img_1_933.jpg	img_3_1001.jpg	img_4_140.jpg
# img_0_1149.jpg	img_1_1033.jpg	img_1_938.jpg	img_3_1005.jpg	img_4_142.jpg
# img_0_1153.jpg	img_1_1037.jpg	img_1_942.jpg	img_3_1007.jpg	img_4_144.jpg
# img_0_1155.jpg	img_1_1038.jpg	img_1_943.jpg	img_3_1008.jpg	img_4_145.jpg
# img_0_1156.jpg	img_1_1039.jpg	img_1_944.jpg	img_3_100.jpg	img_4_147.jpg
# img_0_1157.jpg	img_1_1040.jpg	img_1_948.jpg	img_3_1012.jpg	img_4_148.jpg
# img_0_1158.jpg	img_1_1042.jpg	img_1_94.jpg	img_3_1014.jpg	img_4_149.jpg
# img_0_1160.jpg	img_1_1047.jpg	img_1_952.jpg	img_3_1017.jpg	img_4_150.jpg
# img_0_1163.jpg	img_1_1048.jpg	img_1_953.jpg	img_3_1018.jpg	img_4_151.jpg
# img_0_1164.jpg	img_1_1049.jpg	img_1_954.jpg	img_3_101.jpg	img_4_154.jpg
# img_0_1167.jpg	img_1_1050.jpg	img_1_958.jpg	img_3_1023.jpg	img_4_157.jpg
# img_0_116.jpg	img_1_1051.jpg	img_1_968.jpg	img_3_1026.jpg	img_4_160.jpg
# img_0_1171.jpg	img_1_1053.jpg	img_1_969.jpg	img_3_1027.jpg	img_4_161.jpg
# img_0_1178.jpg	img_1_1055.jpg	img_1_96.jpg	img_3_1028.jpg	img_4_168.jpg
# img_0_1187.jpg	img_1_1058.jpg	img_1_970.jpg	img_3_1030.jpg	img_4_16.jpg
# img_0_1188.jpg	img_1_1060.jpg	img_1_973.jpg	img_3_1032.jpg	img_4_172.jpg
# img_0_1189.jpg	img_1_1061.jpg	img_1_97.jpg	img_3_1033.jpg	img_4_175.jpg
# img_0_1190.jpg	img_1_1063.jpg	img_1_980.jpg	img_3_1035.jpg	img_4_179.jpg
# img_0_1193.jpg	img_1_1064.jpg	img_1_983.jpg	img_3_1037.jpg	img_4_17.jpg
# img_0_1195.jpg	img_1_1065.jpg	img_1_984.jpg	img_3_1040.jpg	img_4_183.jpg
# img_0_1198.jpg	img_1_1066.jpg	img_1_987.jpg	img_3_1042.jpg	img_4_184.jpg
# img_0_1199.jpg	img_1_1067.jpg	img_1_988.jpg	img_3_1044.jpg	img_4_186.jpg
# img_0_1203.jpg	img_1_1068.jpg	img_1_989.jpg	img_3_1045.jpg	img_4_188.jpg
# img_0_120.jpg	img_1_1074.jpg	img_1_993.jpg	img_3_1046.jpg	img_4_18.jpg
# img_0_1211.jpg	img_1_1077.jpg	img_1_995.jpg	img_3_1047.jpg	img_4_192.jpg
# img_0_1215.jpg	img_1_1078.jpg	img_1_996.jpg	img_3_1048.jpg	img_4_193.jpg
# img_0_1216.jpg	img_1_107.jpg	img_1_997.jpg	img_3_1049.jpg	img_4_198.jpg
# img_0_1217.jpg	img_1_1084.jpg	img_2_1002.jpg	img_3_104.jpg	img_4_199.jpg
# img_0_121.jpg	img_1_1087.jpg	img_2_1004.jpg	img_3_106.jpg	img_4_19.jpg
# img_0_122.jpg	img_1_1088.jpg	img_2_1005.jpg	img_3_10.jpg	img_4_201.jpg
# img_0_123.jpg	img_1_1093.jpg	img_2_1007.jpg	img_3_112.jpg	img_4_203.jpg
# img_0_124.jpg	img_1_1095.jpg	img_2_1012.jpg	img_3_113.jpg	img_4_204.jpg
# img_0_125.jpg	img_1_1099.jpg	img_2_1013.jpg	img_3_114.jpg	img_4_206.jpg
# img_0_126.jpg	img_1_1102.jpg	img_2_1014.jpg	img_3_116.jpg	img_4_207.jpg
# img_0_127.jpg	img_1_1103.jpg	img_2_101.jpg	img_3_117.jpg	img_4_215.jpg
# img_0_128.jpg	img_1_1105.jpg	img_2_1024.jpg	img_3_118.jpg	img_4_217.jpg
# img_0_129.jpg	img_1_1106.jpg	img_2_1026.jpg	img_3_120.jpg	img_4_218.jpg
# img_0_12.jpg	img_1_1108.jpg	img_2_1027.jpg	img_3_122.jpg	img_4_219.jpg
# img_0_130.jpg	img_1_1113.jpg	img_2_1028.jpg	img_3_123.jpg	img_4_222.jpg
# img_0_132.jpg	img_1_1115.jpg	img_2_1029.jpg	img_3_124.jpg	img_4_223.jpg
# img_0_133.jpg	img_1_1117.jpg	img_2_1030.jpg	img_3_126.jpg	img_4_228.jpg
# img_0_134.jpg	img_1_111.jpg	img_2_1035.jpg	img_3_127.jpg	img_4_229.jpg
# img_0_139.jpg	img_1_1120.jpg	img_2_1036.jpg	img_3_128.jpg	img_4_22.jpg
# img_0_13.jpg	img_1_1121.jpg	img_2_1038.jpg	img_3_130.jpg	img_4_233.jpg
# img_0_142.jpg	img_1_1126.jpg	img_2_1045.jpg	img_3_131.jpg	img_4_234.jpg
# img_0_145.jpg	img_1_1127.jpg	img_2_1047.jpg	img_3_133.jpg	img_4_235.jpg
# img_0_147.jpg	img_1_1134.jpg	img_2_1049.jpg	img_3_134.jpg	img_4_239.jpg
# img_0_149.jpg	img_1_1135.jpg	img_2_1054.jpg	img_3_135.jpg	img_4_241.jpg
# img_0_14.jpg	img_1_1136.jpg	img_2_1055.jpg	img_3_136.jpg	img_4_242.jpg
# img_0_155.jpg	img_1_1139.jpg	img_2_1057.jpg	img_3_137.jpg	img_4_244.jpg
# img_0_159.jpg	img_1_113.jpg	img_2_1058.jpg	img_3_138.jpg	img_4_245.jpg
# img_0_15.jpg	img_1_1140.jpg	img_2_1059.jpg	img_3_13.jpg	img_4_247.jpg
# img_0_164.jpg	img_1_1141.jpg	img_2_1062.jpg	img_3_142.jpg	img_4_249.jpg
# img_0_166.jpg	img_1_1142.jpg	img_2_1064.jpg	img_3_143.jpg	img_4_24.jpg
# img_0_167.jpg	img_1_1146.jpg	img_2_1066.jpg	img_3_144.jpg	img_4_250.jpg
# img_0_168.jpg	img_1_1148.jpg	img_2_1069.jpg	img_3_145.jpg	img_4_252.jpg
# img_0_170.jpg	img_1_114.jpg	img_2_1070.jpg	img_3_147.jpg	img_4_253.jpg
# img_0_171.jpg	img_1_1150.jpg	img_2_1071.jpg	img_3_148.jpg	img_4_257.jpg
# img_0_172.jpg	img_1_1153.jpg	img_2_1072.jpg	img_3_14.jpg	img_4_258.jpg
# img_0_173.jpg	img_1_1158.jpg	img_2_1074.jpg	img_3_150.jpg	img_4_259.jpg
# img_0_175.jpg	img_1_1159.jpg	img_2_1076.jpg	img_3_151.jpg	img_4_25.jpg
# img_0_176.jpg	img_1_1165.jpg	img_2_1077.jpg	img_3_152.jpg	img_4_260.jpg
# img_0_179.jpg	img_1_1166.jpg	img_2_107.jpg	img_3_153.jpg	img_4_263.jpg
# img_0_181.jpg	img_1_1167.jpg	img_2_1082.jpg	img_3_154.jpg	img_4_264.jpg
# img_0_182.jpg	img_1_1169.jpg	img_2_108.jpg	img_3_156.jpg	img_4_265.jpg
# img_0_185.jpg	img_1_1173.jpg	img_2_112.jpg	img_3_159.jpg	img_4_268.jpg
# img_0_186.jpg	img_1_1174.jpg	img_2_113.jpg	img_3_15.jpg	img_4_271.jpg
# img_0_187.jpg	img_1_1175.jpg	img_2_115.jpg	img_3_162.jpg	img_4_272.jpg
# img_0_188.jpg	img_1_1176.jpg	img_2_116.jpg	img_3_164.jpg	img_4_273.jpg
# img_0_189.jpg	img_1_1182.jpg	img_2_117.jpg	img_3_167.jpg	img_4_274.jpg
# img_0_190.jpg	img_1_1184.jpg	img_2_119.jpg	img_3_16.jpg	img_4_275.jpg
# img_0_191.jpg	img_1_1185.jpg	img_2_120.jpg	img_3_170.jpg	img_4_277.jpg
# img_0_193.jpg	img_1_1186.jpg	img_2_121.jpg	img_3_171.jpg	img_4_279.jpg
# img_0_195.jpg	img_1_1187.jpg	img_2_123.jpg	img_3_173.jpg	img_4_27.jpg
# img_0_196.jpg	img_1_118.jpg	img_2_127.jpg	img_3_175.jpg	img_4_280.jpg
# img_0_197.jpg	img_1_1190.jpg	img_2_129.jpg	img_3_176.jpg	img_4_281.jpg
# img_0_198.jpg	img_1_1191.jpg	img_2_12.jpg	img_3_177.jpg	img_4_283.jpg
# img_0_199.jpg	img_1_1193.jpg	img_2_133.jpg	img_3_17.jpg	img_4_285.jpg
# img_0_19.jpg	img_1_1194.jpg	img_2_134.jpg	img_3_184.jpg	img_4_286.jpg
# img_0_1.jpg	img_1_1195.jpg	img_2_136.jpg	img_3_187.jpg	img_4_287.jpg
# img_0_200.jpg	img_1_119.jpg	img_2_137.jpg	img_3_189.jpg	img_4_288.jpg
# img_0_201.jpg	img_1_11.jpg	img_2_140.jpg	img_3_192.jpg	img_4_291.jpg
# img_0_204.jpg	img_1_1200.jpg	img_2_141.jpg	img_3_197.jpg	img_4_292.jpg
# img_0_206.jpg	img_1_1201.jpg	img_2_149.jpg	img_3_198.jpg	img_4_293.jpg
# img_0_207.jpg	img_1_1202.jpg	img_2_14.jpg	img_3_199.jpg	img_4_2.jpg
# img_0_209.jpg	img_1_1203.jpg	img_2_154.jpg	img_3_204.jpg	img_4_300.jpg
# img_0_210.jpg	img_1_1204.jpg	img_2_156.jpg	img_3_207.jpg	img_4_302.jpg
# img_0_211.jpg	img_1_1212.jpg	img_2_157.jpg	img_3_20.jpg	img_4_303.jpg
# img_0_212.jpg	img_1_1214.jpg	img_2_160.jpg	img_3_213.jpg	img_4_304.jpg
# img_0_214.jpg	img_1_1216.jpg	img_2_161.jpg	img_3_215.jpg	img_4_306.jpg
# img_0_215.jpg	img_1_1220.jpg	img_2_162.jpg	img_3_216.jpg	img_4_307.jpg
# img_0_216.jpg	img_1_1221.jpg	img_2_163.jpg	img_3_217.jpg	img_4_311.jpg
# img_0_218.jpg	img_1_1222.jpg	img_2_165.jpg	img_3_218.jpg	img_4_312.jpg
# img_0_219.jpg	img_1_1223.jpg	img_2_166.jpg	img_3_219.jpg	img_4_314.jpg
# img_0_21.jpg	img_1_1227.jpg	img_2_167.jpg	img_3_221.jpg	img_4_315.jpg
# img_0_227.jpg	img_1_1229.jpg	img_2_168.jpg	img_3_224.jpg	img_4_318.jpg
# img_0_228.jpg	img_1_1235.jpg	img_2_170.jpg	img_3_227.jpg	img_4_319.jpg
# img_0_230.jpg	img_1_1236.jpg	img_2_171.jpg	img_3_228.jpg	img_4_321.jpg
# img_0_231.jpg	img_1_1237.jpg	img_2_172.jpg	img_3_235.jpg	img_4_323.jpg
# img_0_239.jpg	img_1_123.jpg	img_2_173.jpg	img_3_236.jpg	img_4_324.jpg
# img_0_23.jpg	img_1_1241.jpg	img_2_174.jpg	img_3_23.jpg	img_4_326.jpg
# img_0_241.jpg	img_1_1242.jpg	img_2_177.jpg	img_3_242.jpg	img_4_328.jpg
# img_0_243.jpg	img_1_1244.jpg	img_2_178.jpg	img_3_244.jpg	img_4_329.jpg
# img_0_248.jpg	img_1_1247.jpg	img_2_179.jpg	img_3_245.jpg	img_4_330.jpg
# img_0_249.jpg	img_1_124.jpg	img_2_17.jpg	img_3_246.jpg	img_4_331.jpg
# img_0_250.jpg	img_1_1250.jpg	img_2_180.jpg	img_3_247.jpg	img_4_332.jpg
# img_0_252.jpg	img_1_1257.jpg	img_2_181.jpg	img_3_252.jpg	img_4_334.jpg
# img_0_253.jpg	img_1_1259.jpg	img_2_182.jpg	img_3_253.jpg	img_4_339.jpg
# img_0_254.jpg	img_1_1261.jpg	img_2_186.jpg	img_3_255.jpg	img_4_342.jpg
# img_0_256.jpg	img_1_1262.jpg	img_2_187.jpg	img_3_257.jpg	img_4_343.jpg
# img_0_258.jpg	img_1_1266.jpg	img_2_189.jpg	img_3_25.jpg	img_4_346.jpg
# img_0_261.jpg	img_1_1268.jpg	img_2_18.jpg	img_3_260.jpg	img_4_347.jpg
# img_0_263.jpg	img_1_126.jpg	img_2_191.jpg	img_3_261.jpg	img_4_349.jpg
# img_0_266.jpg	img_1_1272.jpg	img_2_192.jpg	img_3_264.jpg	img_4_354.jpg
# img_0_269.jpg	img_1_1276.jpg	img_2_193.jpg	img_3_266.jpg	img_4_355.jpg
# img_0_270.jpg	img_1_127.jpg	img_2_1.jpg	img_3_26.jpg	img_4_358.jpg
# img_0_271.jpg	img_1_1281.jpg	img_2_204.jpg	img_3_270.jpg	img_4_359.jpg
# img_0_272.jpg	img_1_1283.jpg	img_2_208.jpg	img_3_273.jpg	img_4_364.jpg
# img_0_278.jpg	img_1_1284.jpg	img_2_212.jpg	img_3_276.jpg	img_4_367.jpg
# img_0_279.jpg	img_1_1285.jpg	img_2_214.jpg	img_3_279.jpg	img_4_368.jpg
# img_0_282.jpg	img_1_1287.jpg	img_2_216.jpg	img_3_27.jpg	img_4_371.jpg
# img_0_283.jpg	img_1_1288.jpg	img_2_217.jpg	img_3_282.jpg	img_4_372.jpg
# img_0_284.jpg	img_1_128.jpg	img_2_221.jpg	img_3_283.jpg	img_4_378.jpg
# img_0_287.jpg	img_1_1291.jpg	img_2_227.jpg	img_3_284.jpg	img_4_380.jpg
# img_0_288.jpg	img_1_1292.jpg	img_2_228.jpg	img_3_288.jpg	img_4_381.jpg
# img_0_289.jpg	img_1_1297.jpg	img_2_229.jpg	img_3_28.jpg	img_4_389.jpg
# img_0_296.jpg	img_1_1299.jpg	img_2_22.jpg	img_3_292.jpg	img_4_395.jpg
# img_0_297.jpg	img_1_1300.jpg	img_2_231.jpg	img_3_293.jpg	img_4_397.jpg
# img_0_299.jpg	img_1_1301.jpg	img_2_234.jpg	img_3_294.jpg	img_4_398.jpg
# img_0_29.jpg	img_1_1302.jpg	img_2_235.jpg	img_3_296.jpg	img_4_399.jpg
# img_0_300.jpg	img_1_1303.jpg	img_2_236.jpg	img_3_29.jpg	img_4_400.jpg
# img_0_303.jpg	img_1_1304.jpg	img_2_23.jpg	img_3_2.jpg	img_4_404.jpg
# img_0_304.jpg	img_1_1307.jpg	img_2_242.jpg	img_3_301.jpg	img_4_409.jpg
# img_0_310.jpg	img_1_1308.jpg	img_2_243.jpg	img_3_305.jpg	img_4_410.jpg
# img_0_311.jpg	img_1_1309.jpg	img_2_246.jpg	img_3_308.jpg	img_4_411.jpg
# img_0_312.jpg	img_1_1311.jpg	img_2_248.jpg	img_3_312.jpg	img_4_414.jpg
# img_0_313.jpg	img_1_1316.jpg	img_2_24.jpg	img_3_315.jpg	img_4_415.jpg
# img_0_31.jpg	img_1_1318.jpg	img_2_251.jpg	img_3_316.jpg	img_4_419.jpg
# img_0_321.jpg	img_1_131.jpg	img_2_252.jpg	img_3_317.jpg	img_4_423.jpg
# img_0_323.jpg	img_1_1320.jpg	img_2_254.jpg	img_3_318.jpg	img_4_425.jpg
# img_0_325.jpg	img_1_133.jpg	img_2_256.jpg	img_3_323.jpg	img_4_426.jpg
# img_0_327.jpg	img_1_138.jpg	img_2_257.jpg	img_3_324.jpg	img_4_427.jpg
# img_0_330.jpg	img_1_139.jpg	img_2_258.jpg	img_3_325.jpg	img_4_428.jpg
# img_0_331.jpg	img_1_13.jpg	img_2_261.jpg	img_3_334.jpg	img_4_429.jpg
# img_0_335.jpg	img_1_147.jpg	img_2_262.jpg	img_3_335.jpg	img_4_42.jpg
# img_0_338.jpg	img_1_150.jpg	img_2_263.jpg	img_3_338.jpg	img_4_434.jpg
# img_0_339.jpg	img_1_151.jpg	img_2_264.jpg	img_3_33.jpg	img_4_438.jpg
# img_0_33.jpg	img_1_154.jpg	img_2_26.jpg	img_3_340.jpg	img_4_440.jpg
# img_0_344.jpg	img_1_156.jpg	img_2_270.jpg	img_3_344.jpg	img_4_442.jpg
# img_0_347.jpg	img_1_157.jpg	img_2_271.jpg	img_3_347.jpg	img_4_443.jpg
# img_0_349.jpg	img_1_158.jpg	img_2_272.jpg	img_3_34.jpg	img_4_447.jpg
# img_0_34.jpg	img_1_159.jpg	img_2_273.jpg	img_3_353.jpg	img_4_448.jpg
# img_0_350.jpg	img_1_161.jpg	img_2_274.jpg	img_3_354.jpg	img_4_449.jpg
# img_0_351.jpg	img_1_162.jpg	img_2_275.jpg	img_3_355.jpg	img_4_44.jpg
# img_0_353.jpg	img_1_163.jpg	img_2_276.jpg	img_3_357.jpg	img_4_450.jpg
# img_0_354.jpg	img_1_169.jpg	img_2_277.jpg	img_3_358.jpg	img_4_451.jpg
# img_0_357.jpg	img_1_170.jpg	img_2_279.jpg	img_3_373.jpg	img_4_455.jpg
# img_0_35.jpg	img_1_171.jpg	img_2_27.jpg	img_3_374.jpg	img_4_456.jpg
# img_0_360.jpg	img_1_173.jpg	img_2_281.jpg	img_3_378.jpg	img_4_457.jpg
# img_0_361.jpg	img_1_177.jpg	img_2_282.jpg	img_3_37.jpg	img_4_458.jpg
# img_0_363.jpg	img_1_178.jpg	img_2_286.jpg	img_3_380.jpg	img_4_45.jpg
# img_0_370.jpg	img_1_179.jpg	img_2_288.jpg	img_3_381.jpg	img_4_460.jpg
# img_0_371.jpg	img_1_17.jpg	img_2_28.jpg	img_3_382.jpg	img_4_461.jpg
# img_0_372.jpg	img_1_182.jpg	img_2_290.jpg	img_3_383.jpg	img_4_462.jpg
# img_0_374.jpg	img_1_183.jpg	img_2_292.jpg	img_3_386.jpg	img_4_463.jpg
# img_0_375.jpg	img_1_185.jpg	img_2_293.jpg	img_3_387.jpg	img_4_464.jpg
# img_0_376.jpg	img_1_186.jpg	img_2_296.jpg	img_3_389.jpg	img_4_46.jpg
# img_0_377.jpg	img_1_187.jpg	img_2_298.jpg	img_3_38.jpg	img_4_470.jpg
# img_0_378.jpg	img_1_189.jpg	img_2_29.jpg	img_3_390.jpg	img_4_471.jpg
# img_0_381.jpg	img_1_190.jpg	img_2_2.jpg	img_3_393.jpg	img_4_472.jpg
# img_0_386.jpg	img_1_193.jpg	img_2_305.jpg	img_3_395.jpg	img_4_473.jpg
# img_0_389.jpg	img_1_194.jpg	img_2_306.jpg	img_3_398.jpg	img_4_474.jpg
# img_0_38.jpg	img_1_199.jpg	img_2_307.jpg	img_3_3.jpg	img_4_478.jpg
# img_0_390.jpg	img_1_19.jpg	img_2_311.jpg	img_3_402.jpg	img_4_479.jpg
# img_0_394.jpg	img_1_1.jpg	img_2_313.jpg	img_3_404.jpg	img_4_47.jpg
# img_0_395.jpg	img_1_200.jpg	img_2_316.jpg	img_3_409.jpg	img_4_481.jpg
# img_0_397.jpg	img_1_201.jpg	img_2_319.jpg	img_3_412.jpg	img_4_482.jpg
# img_0_399.jpg	img_1_203.jpg	img_2_31.jpg	img_3_414.jpg	img_4_484.jpg
# img_0_400.jpg	img_1_204.jpg	img_2_320.jpg	img_3_416.jpg	img_4_485.jpg
# img_0_401.jpg	img_1_205.jpg	img_2_327.jpg	img_3_417.jpg	img_4_486.jpg
# img_0_402.jpg	img_1_209.jpg	img_2_329.jpg	img_3_419.jpg	img_4_487.jpg
# img_0_403.jpg	img_1_20.jpg	img_2_331.jpg	img_3_41.jpg	img_4_490.jpg
# img_0_405.jpg	img_1_212.jpg	img_2_332.jpg	img_3_423.jpg	img_4_492.jpg
# img_0_411.jpg	img_1_214.jpg	img_2_334.jpg	img_3_424.jpg	img_4_493.jpg
# img_0_415.jpg	img_1_216.jpg	img_2_336.jpg	img_3_425.jpg	img_4_498.jpg
# img_0_416.jpg	img_1_218.jpg	img_2_337.jpg	img_3_426.jpg	img_4_504.jpg
# img_0_417.jpg	img_1_221.jpg	img_2_339.jpg	img_3_427.jpg	img_4_506.jpg
# img_0_419.jpg	img_1_222.jpg	img_2_340.jpg	img_3_429.jpg	img_4_507.jpg
# img_0_41.jpg	img_1_228.jpg	img_2_341.jpg	img_3_433.jpg	img_4_508.jpg
# img_0_420.jpg	img_1_229.jpg	img_2_345.jpg	img_3_434.jpg	img_4_509.jpg
# img_0_421.jpg	img_1_230.jpg	img_2_349.jpg	img_3_441.jpg	img_4_50.jpg
# img_0_422.jpg	img_1_231.jpg	img_2_34.jpg	img_3_444.jpg	img_4_510.jpg
# img_0_423.jpg	img_1_232.jpg	img_2_350.jpg	img_3_448.jpg	img_4_516.jpg
# img_0_425.jpg	img_1_234.jpg	img_2_352.jpg	img_3_456.jpg	img_4_519.jpg
# img_0_426.jpg	img_1_236.jpg	img_2_353.jpg	img_3_45.jpg	img_4_521.jpg
# img_0_427.jpg	img_1_239.jpg	img_2_355.jpg	img_3_461.jpg	img_4_525.jpg
# img_0_428.jpg	img_1_23.jpg	img_2_359.jpg	img_3_463.jpg	img_4_526.jpg
# img_0_430.jpg	img_1_240.jpg	img_2_35.jpg	img_3_468.jpg	img_4_528.jpg
# img_0_431.jpg	img_1_241.jpg	img_2_360.jpg	img_3_472.jpg	img_4_52.jpg
# img_0_432.jpg	img_1_242.jpg	img_2_361.jpg	img_3_473.jpg	img_4_530.jpg
# img_0_433.jpg	img_1_246.jpg	img_2_362.jpg	img_3_474.jpg	img_4_531.jpg
# img_0_435.jpg	img_1_247.jpg	img_2_363.jpg	img_3_476.jpg	img_4_532.jpg
# img_0_437.jpg	img_1_248.jpg	img_2_364.jpg	img_3_480.jpg	img_4_533.jpg
# img_0_438.jpg	img_1_250.jpg	img_2_367.jpg	img_3_482.jpg	img_4_534.jpg
# img_0_439.jpg	img_1_255.jpg	img_2_369.jpg	img_3_48.jpg	img_4_536.jpg
# img_0_449.jpg	img_1_256.jpg	img_2_36.jpg	img_3_494.jpg	img_4_538.jpg
# img_0_450.jpg	img_1_257.jpg	img_2_370.jpg	img_3_496.jpg	img_4_539.jpg
# img_0_453.jpg	img_1_260.jpg	img_2_372.jpg	img_3_498.jpg	img_4_543.jpg
# img_0_454.jpg	img_1_265.jpg	img_2_373.jpg	img_3_49.jpg	img_4_544.jpg
# img_0_457.jpg	img_1_266.jpg	img_2_374.jpg	img_3_4.jpg	img_4_547.jpg
# img_0_459.jpg	img_1_267.jpg	img_2_377.jpg	img_3_500.jpg	img_4_550.jpg
# img_0_460.jpg	img_1_269.jpg	img_2_37.jpg	img_3_502.jpg	img_4_552.jpg
# img_0_461.jpg	img_1_270.jpg	img_2_380.jpg	img_3_505.jpg	img_4_554.jpg
# img_0_462.jpg	img_1_271.jpg	img_2_381.jpg	img_3_506.jpg	img_4_555.jpg
# img_0_463.jpg	img_1_272.jpg	img_2_383.jpg	img_3_507.jpg	img_4_557.jpg
# img_0_466.jpg	img_1_279.jpg	img_2_386.jpg	img_3_509.jpg	img_4_55.jpg
# img_0_467.jpg	img_1_281.jpg	img_2_388.jpg	img_3_511.jpg	img_4_560.jpg
# img_0_471.jpg	img_1_283.jpg	img_2_389.jpg	img_3_512.jpg	img_4_569.jpg
# img_0_472.jpg	img_1_285.jpg	img_2_390.jpg	img_3_514.jpg	img_4_572.jpg
# img_0_473.jpg	img_1_286.jpg	img_2_391.jpg	img_3_515.jpg	img_4_573.jpg
# img_0_475.jpg	img_1_288.jpg	img_2_393.jpg	img_3_517.jpg	img_4_577.jpg
# img_0_476.jpg	img_1_289.jpg	img_2_394.jpg	img_3_519.jpg	img_4_579.jpg
# img_0_477.jpg	img_1_291.jpg	img_2_395.jpg	img_3_520.jpg	img_4_581.jpg
# img_0_480.jpg	img_1_293.jpg	img_2_398.jpg	img_3_521.jpg	img_4_582.jpg
# img_0_481.jpg	img_1_298.jpg	img_2_399.jpg	img_3_526.jpg	img_4_583.jpg
# img_0_482.jpg	img_1_29.jpg	img_2_400.jpg	img_3_529.jpg	img_4_588.jpg
# img_0_484.jpg	img_1_301.jpg	img_2_401.jpg	img_3_530.jpg	img_4_591.jpg
# img_0_487.jpg	img_1_303.jpg	img_2_408.jpg	img_3_534.jpg	img_4_593.jpg
# img_0_488.jpg	img_1_309.jpg	img_2_410.jpg	img_3_537.jpg	img_4_594.jpg
# img_0_489.jpg	img_1_30.jpg	img_2_413.jpg	img_3_540.jpg	img_4_597.jpg
# img_0_494.jpg	img_1_312.jpg	img_2_415.jpg	img_3_541.jpg	img_4_599.jpg
# img_0_496.jpg	img_1_318.jpg	img_2_419.jpg	img_3_543.jpg	img_4_59.jpg
# img_0_49.jpg	img_1_319.jpg	img_2_423.jpg	img_3_545.jpg	img_4_602.jpg
# img_0_502.jpg	img_1_31.jpg	img_2_425.jpg	img_3_546.jpg	img_4_603.jpg
# img_0_504.jpg	img_1_320.jpg	img_2_426.jpg	img_3_547.jpg	img_4_60.jpg
# img_0_505.jpg	img_1_321.jpg	img_2_428.jpg	img_3_548.jpg	img_4_611.jpg
# img_0_507.jpg	img_1_322.jpg	img_2_430.jpg	img_3_54.jpg	img_4_612.jpg
# img_0_508.jpg	img_1_325.jpg	img_2_431.jpg	img_3_551.jpg	img_4_613.jpg
# img_0_511.jpg	img_1_328.jpg	img_2_433.jpg	img_3_564.jpg	img_4_614.jpg
# img_0_512.jpg	img_1_32.jpg	img_2_436.jpg	img_3_567.jpg	img_4_617.jpg
# img_0_518.jpg	img_1_330.jpg	img_2_440.jpg	img_3_571.jpg	img_4_61.jpg
# img_0_520.jpg	img_1_334.jpg	img_2_441.jpg	img_3_572.jpg	img_4_620.jpg
# img_0_522.jpg	img_1_335.jpg	img_2_442.jpg	img_3_573.jpg	img_4_621.jpg
# img_0_525.jpg	img_1_33.jpg	img_2_446.jpg	img_3_575.jpg	img_4_624.jpg
# img_0_528.jpg	img_1_340.jpg	img_2_448.jpg	img_3_57.jpg	img_4_628.jpg
# img_0_529.jpg	img_1_344.jpg	img_2_449.jpg	img_3_582.jpg	img_4_62.jpg
# img_0_531.jpg	img_1_346.jpg	img_2_450.jpg	img_3_584.jpg	img_4_630.jpg
# img_0_532.jpg	img_1_351.jpg	img_2_453.jpg	img_3_587.jpg	img_4_634.jpg
# img_0_535.jpg	img_1_353.jpg	img_2_454.jpg	img_3_589.jpg	img_4_635.jpg
# img_0_536.jpg	img_1_355.jpg	img_2_45.jpg	img_3_58.jpg	img_4_637.jpg
# img_0_538.jpg	img_1_357.jpg	img_2_461.jpg	img_3_590.jpg	img_4_641.jpg
# img_0_539.jpg	img_1_358.jpg	img_2_465.jpg	img_3_594.jpg	img_4_643.jpg
# img_0_53.jpg	img_1_35.jpg	img_2_469.jpg	img_3_595.jpg	img_4_644.jpg
# img_0_541.jpg	img_1_363.jpg	img_2_470.jpg	img_3_597.jpg	img_4_64.jpg
# img_0_542.jpg	img_1_365.jpg	img_2_471.jpg	img_3_599.jpg	img_4_651.jpg
# img_0_543.jpg	img_1_366.jpg	img_2_472.jpg	img_3_59.jpg	img_4_652.jpg
# img_0_545.jpg	img_1_367.jpg	img_2_474.jpg	img_3_5.jpg	img_4_655.jpg
# img_0_546.jpg	img_1_372.jpg	img_2_476.jpg	img_3_601.jpg	img_4_656.jpg
# img_0_548.jpg	img_1_376.jpg	img_2_478.jpg	img_3_602.jpg	img_4_65.jpg
# img_0_54.jpg	img_1_377.jpg	img_2_479.jpg	img_3_603.jpg	img_4_660.jpg
# img_0_555.jpg	img_1_382.jpg	img_2_47.jpg	img_3_604.jpg	img_4_661.jpg
# img_0_557.jpg	img_1_384.jpg	img_2_482.jpg	img_3_605.jpg	img_4_662.jpg
# img_0_55.jpg	img_1_385.jpg	img_2_483.jpg	img_3_606.jpg	img_4_666.jpg
# img_0_560.jpg	img_1_389.jpg	img_2_485.jpg	img_3_608.jpg	img_4_669.jpg
# img_0_563.jpg	img_1_392.jpg	img_2_48.jpg	img_3_610.jpg	img_4_673.jpg
# img_0_564.jpg	img_1_394.jpg	img_2_491.jpg	img_3_612.jpg	img_4_675.jpg
# img_0_569.jpg	img_1_395.jpg	img_2_492.jpg	img_3_619.jpg	img_4_676.jpg
# img_0_56.jpg	img_1_396.jpg	img_2_495.jpg	img_3_61.jpg	img_4_677.jpg
# img_0_572.jpg	img_1_399.jpg	img_2_498.jpg	img_3_621.jpg	img_4_67.jpg
# img_0_573.jpg	img_1_39.jpg	img_2_503.jpg	img_3_624.jpg	img_4_681.jpg
# img_0_574.jpg	img_1_400.jpg	img_2_50.jpg	img_3_626.jpg	img_4_682.jpg
# img_0_575.jpg	img_1_405.jpg	img_2_510.jpg	img_3_628.jpg	img_4_683.jpg
# img_0_577.jpg	img_1_408.jpg	img_2_513.jpg	img_3_62.jpg	img_4_687.jpg
# img_0_578.jpg	img_1_409.jpg	img_2_514.jpg	img_3_630.jpg	img_4_688.jpg
# img_0_579.jpg	img_1_410.jpg	img_2_516.jpg	img_3_632.jpg	img_4_695.jpg
# img_0_584.jpg	img_1_411.jpg	img_2_517.jpg	img_3_634.jpg	img_4_697.jpg
# img_0_585.jpg	img_1_414.jpg	img_2_519.jpg	img_3_643.jpg	img_4_698.jpg
# img_0_586.jpg	img_1_415.jpg	img_2_520.jpg	img_3_644.jpg	img_4_699.jpg
# img_0_588.jpg	img_1_418.jpg	img_2_522.jpg	img_3_645.jpg	img_4_706.jpg
# img_0_589.jpg	img_1_419.jpg	img_2_528.jpg	img_3_646.jpg	img_4_707.jpg
# img_0_595.jpg	img_1_41.jpg	img_2_529.jpg	img_3_648.jpg	img_4_708.jpg
# img_0_596.jpg	img_1_429.jpg	img_2_52.jpg	img_3_649.jpg	img_4_70.jpg
# img_0_598.jpg	img_1_430.jpg	img_2_531.jpg	img_3_651.jpg	img_4_711.jpg
# img_0_599.jpg	img_1_431.jpg	img_2_533.jpg	img_3_652.jpg	img_4_713.jpg
# img_0_600.jpg	img_1_432.jpg	img_2_536.jpg	img_3_658.jpg	img_4_716.jpg
# img_0_602.jpg	img_1_434.jpg	img_2_539.jpg	img_3_662.jpg	img_4_717.jpg
# img_0_604.jpg	img_1_438.jpg	img_2_53.jpg	img_3_663.jpg	img_4_718.jpg
# img_0_605.jpg	img_1_439.jpg	img_2_541.jpg	img_3_665.jpg	img_4_719.jpg
# img_0_611.jpg	img_1_43.jpg	img_2_543.jpg	img_3_666.jpg	img_4_721.jpg
# img_0_613.jpg	img_1_444.jpg	img_2_544.jpg	img_3_667.jpg	img_4_723.jpg
# img_0_614.jpg	img_1_446.jpg	img_2_546.jpg	img_3_668.jpg	img_4_725.jpg
# img_0_625.jpg	img_1_448.jpg	img_2_549.jpg	img_3_670.jpg	img_4_728.jpg
# img_0_626.jpg	img_1_449.jpg	img_2_553.jpg	img_3_675.jpg	img_4_730.jpg
# img_0_62.jpg	img_1_450.jpg	img_2_554.jpg	img_3_679.jpg	img_4_731.jpg
# img_0_630.jpg	img_1_451.jpg	img_2_558.jpg	img_3_682.jpg	img_4_734.jpg
# img_0_639.jpg	img_1_452.jpg	img_2_559.jpg	img_3_687.jpg	img_4_737.jpg
# img_0_641.jpg	img_1_454.jpg	img_2_55.jpg	img_3_688.jpg	img_4_738.jpg
# img_0_642.jpg	img_1_456.jpg	img_2_560.jpg	img_3_689.jpg	img_4_739.jpg
# img_0_644.jpg	img_1_458.jpg	img_2_563.jpg	img_3_690.jpg	img_4_740.jpg
# img_0_646.jpg	img_1_459.jpg	img_2_569.jpg	img_3_692.jpg	img_4_741.jpg
# img_0_647.jpg	img_1_460.jpg	img_2_56.jpg	img_3_694.jpg	img_4_743.jpg
# img_0_650.jpg	img_1_461.jpg	img_2_570.jpg	img_3_696.jpg	img_4_747.jpg
# img_0_652.jpg	img_1_462.jpg	img_2_573.jpg	img_3_69.jpg	img_4_749.jpg
# img_0_656.jpg	img_1_463.jpg	img_2_574.jpg	img_3_701.jpg	img_4_750.jpg
# img_0_658.jpg	img_1_464.jpg	img_2_575.jpg	img_3_705.jpg	img_4_752.jpg
# img_0_65.jpg	img_1_466.jpg	img_2_576.jpg	img_3_706.jpg	img_4_754.jpg
# img_0_660.jpg	img_1_472.jpg	img_2_577.jpg	img_3_707.jpg	img_4_755.jpg
# img_0_665.jpg	img_1_473.jpg	img_2_578.jpg	img_3_709.jpg	img_4_756.jpg
# img_0_666.jpg	img_1_474.jpg	img_2_579.jpg	img_3_710.jpg	img_4_759.jpg
# img_0_668.jpg	img_1_483.jpg	img_2_57.jpg	img_3_712.jpg	img_4_761.jpg
# img_0_669.jpg	img_1_485.jpg	img_2_580.jpg	img_3_718.jpg	img_4_763.jpg
# img_0_670.jpg	img_1_491.jpg	img_2_581.jpg	img_3_719.jpg	img_4_764.jpg
# img_0_673.jpg	img_1_492.jpg	img_2_582.jpg	img_3_721.jpg	img_4_766.jpg
# img_0_674.jpg	img_1_495.jpg	img_2_583.jpg	img_3_722.jpg	img_4_767.jpg
# img_0_675.jpg	img_1_496.jpg	img_2_586.jpg	img_3_724.jpg	img_4_768.jpg
# img_0_676.jpg	img_1_499.jpg	img_2_591.jpg	img_3_725.jpg	img_4_76.jpg
# img_0_679.jpg	img_1_4.jpg	img_2_593.jpg	img_3_726.jpg	img_4_771.jpg
# img_0_67.jpg	img_1_502.jpg	img_2_595.jpg	img_3_727.jpg	img_4_776.jpg
# img_0_683.jpg	img_1_506.jpg	img_2_597.jpg	img_3_728.jpg	img_4_777.jpg
# img_0_689.jpg	img_1_507.jpg	img_2_599.jpg	img_3_730.jpg	img_4_779.jpg
# img_0_692.jpg	img_1_50.jpg	img_2_59.jpg	img_3_731.jpg	img_4_77.jpg
# img_0_693.jpg	img_1_510.jpg	img_2_5.jpg	img_3_732.jpg	img_4_781.jpg
# img_0_695.jpg	img_1_511.jpg	img_2_601.jpg	img_3_733.jpg	img_4_783.jpg
# img_0_697.jpg	img_1_512.jpg	img_2_602.jpg	img_3_736.jpg	img_4_785.jpg
# img_0_6.jpg	img_1_513.jpg	img_2_607.jpg	img_3_737.jpg	img_4_78.jpg
# img_0_700.jpg	img_1_515.jpg	img_2_60.jpg	img_3_739.jpg	img_4_793.jpg
# img_0_702.jpg	img_1_518.jpg	img_2_610.jpg	img_3_740.jpg	img_4_797.jpg
# img_0_703.jpg	img_1_519.jpg	img_2_614.jpg	img_3_741.jpg	img_4_798.jpg
# img_0_706.jpg	img_1_521.jpg	img_2_616.jpg	img_3_742.jpg	img_4_79.jpg
# img_0_708.jpg	img_1_522.jpg	img_2_617.jpg	img_3_744.jpg	img_4_7.jpg
# img_0_709.jpg	img_1_523.jpg	img_2_618.jpg	img_3_745.jpg	img_4_800.jpg
# img_0_70.jpg	img_1_525.jpg	img_2_619.jpg	img_3_746.jpg	img_4_801.jpg
# img_0_713.jpg	img_1_526.jpg	img_2_61.jpg	img_3_748.jpg	img_4_803.jpg
# img_0_719.jpg	img_1_529.jpg	img_2_623.jpg	img_3_74.jpg	img_4_804.jpg
# img_0_720.jpg	img_1_52.jpg	img_2_629.jpg	img_3_751.jpg	img_4_806.jpg
# img_0_721.jpg	img_1_533.jpg	img_2_632.jpg	img_3_752.jpg	img_4_808.jpg
# img_0_723.jpg	img_1_536.jpg	img_2_633.jpg	img_3_754.jpg	img_4_810.jpg
# img_0_724.jpg	img_1_540.jpg	img_2_634.jpg	img_3_755.jpg	img_4_814.jpg
# img_0_727.jpg	img_1_541.jpg	img_2_636.jpg	img_3_756.jpg	img_4_818.jpg
# img_0_728.jpg	img_1_546.jpg	img_2_637.jpg	img_3_757.jpg	img_4_81.jpg
# img_0_730.jpg	img_1_552.jpg	img_2_638.jpg	img_3_761.jpg	img_4_821.jpg
# img_0_736.jpg	img_1_553.jpg	img_2_640.jpg	img_3_762.jpg	img_4_822.jpg
# img_0_737.jpg	img_1_555.jpg	img_2_643.jpg	img_3_763.jpg	img_4_828.jpg
# img_0_739.jpg	img_1_558.jpg	img_2_644.jpg	img_3_764.jpg	img_4_829.jpg
# img_0_740.jpg	img_1_559.jpg	img_2_646.jpg	img_3_767.jpg	img_4_833.jpg
# img_0_741.jpg	img_1_55.jpg	img_2_647.jpg	img_3_770.jpg	img_4_835.jpg
# img_0_743.jpg	img_1_560.jpg	img_2_650.jpg	img_3_772.jpg	img_4_836.jpg
# img_0_744.jpg	img_1_562.jpg	img_2_651.jpg	img_3_775.jpg	img_4_837.jpg
# img_0_745.jpg	img_1_563.jpg	img_2_653.jpg	img_3_779.jpg	img_4_838.jpg
# img_0_746.jpg	img_1_564.jpg	img_2_656.jpg	img_3_780.jpg	img_4_83.jpg
# img_0_747.jpg	img_1_566.jpg	img_2_658.jpg	img_3_782.jpg	img_4_840.jpg
# img_0_750.jpg	img_1_56.jpg	img_2_659.jpg	img_3_783.jpg	img_4_843.jpg
# img_0_752.jpg	img_1_573.jpg	img_2_660.jpg	img_3_784.jpg	img_4_844.jpg
# img_0_754.jpg	img_1_576.jpg	img_2_661.jpg	img_3_785.jpg	img_4_848.jpg
# img_0_755.jpg	img_1_577.jpg	img_2_662.jpg	img_3_787.jpg	img_4_84.jpg
# img_0_757.jpg	img_1_580.jpg	img_2_663.jpg	img_3_790.jpg	img_4_850.jpg
# img_0_759.jpg	img_1_584.jpg	img_2_667.jpg	img_3_792.jpg	img_4_852.jpg
# img_0_760.jpg	img_1_585.jpg	img_2_669.jpg	img_3_796.jpg	img_4_855.jpg
# img_0_763.jpg	img_1_586.jpg	img_2_670.jpg	img_3_797.jpg	img_4_856.jpg
# img_0_765.jpg	img_1_58.jpg	img_2_671.jpg	img_3_799.jpg	img_4_859.jpg
# img_0_766.jpg	img_1_594.jpg	img_2_673.jpg	img_3_7.jpg	img_4_85.jpg
# img_0_767.jpg	img_1_596.jpg	img_2_675.jpg	img_3_801.jpg	img_4_861.jpg
# img_0_768.jpg	img_1_597.jpg	img_2_678.jpg	img_3_802.jpg	img_4_862.jpg
# img_0_769.jpg	img_1_59.jpg	img_2_680.jpg	img_3_804.jpg	img_4_865.jpg
# ...
# img_0_564.jpg	img_1_675.jpg	img_2_578.jpg	img_3_49.jpg	img_4_484.jpg
# img_0_567.jpg	img_1_676.jpg	img_2_582.jpg	img_3_4.jpg	img_4_486.jpg
# img_0_56.jpg	img_1_679.jpg	img_2_583.jpg	img_3_503.jpg	img_4_487.jpg
# img_0_572.jpg	img_1_680.jpg	img_2_58.jpg	img_3_506.jpg	img_4_489.jpg
# img_0_576.jpg	img_1_684.jpg	img_2_590.jpg	img_3_510.jpg	img_4_491.jpg
# img_0_57.jpg	img_1_686.jpg	img_2_591.jpg	img_3_516.jpg	img_4_493.jpg
# img_0_584.jpg	img_1_687.jpg	img_2_593.jpg	img_3_517.jpg	img_4_494.jpg
# img_0_585.jpg	img_1_691.jpg	img_2_596.jpg	img_3_522.jpg	img_4_497.jpg
# img_0_586.jpg	img_1_693.jpg	img_2_597.jpg	img_3_528.jpg	img_4_4.jpg
# img_0_590.jpg	img_1_699.jpg	img_2_598.jpg	img_3_529.jpg	img_4_500.jpg
# img_0_592.jpg	img_1_69.jpg	img_2_600.jpg	img_3_542.jpg	img_4_501.jpg
# img_0_597.jpg	img_1_6.jpg	img_2_602.jpg	img_3_543.jpg	img_4_504.jpg
# img_0_600.jpg	img_1_700.jpg	img_2_606.jpg	img_3_546.jpg	img_4_505.jpg
# img_0_601.jpg	img_1_702.jpg	img_2_607.jpg	img_3_558.jpg	img_4_506.jpg
# img_0_604.jpg	img_1_710.jpg	img_2_608.jpg	img_3_55.jpg	img_4_50.jpg
# img_0_60.jpg	img_1_711.jpg	img_2_609.jpg	img_3_564.jpg	img_4_516.jpg
# img_0_610.jpg	img_1_713.jpg	img_2_610.jpg	img_3_566.jpg	img_4_519.jpg
# img_0_611.jpg	img_1_717.jpg	img_2_615.jpg	img_3_572.jpg	img_4_51.jpg
# img_0_612.jpg	img_1_720.jpg	img_2_618.jpg	img_3_573.jpg	img_4_521.jpg
# img_0_615.jpg	img_1_721.jpg	img_2_620.jpg	img_3_575.jpg	img_4_523.jpg
# img_0_618.jpg	img_1_725.jpg	img_2_621.jpg	img_3_57.jpg	img_4_524.jpg
# img_0_621.jpg	img_1_727.jpg	img_2_629.jpg	img_3_582.jpg	img_4_529.jpg
# img_0_626.jpg	img_1_729.jpg	img_2_638.jpg	img_3_583.jpg	img_4_52.jpg
# img_0_639.jpg	img_1_731.jpg	img_2_63.jpg	img_3_586.jpg	img_4_532.jpg
# img_0_642.jpg	img_1_732.jpg	img_2_640.jpg	img_3_587.jpg	img_4_533.jpg
# img_0_645.jpg	img_1_733.jpg	img_2_643.jpg	img_3_591.jpg	img_4_535.jpg
# img_0_647.jpg	img_1_736.jpg	img_2_646.jpg	img_3_592.jpg	img_4_537.jpg
# img_0_648.jpg	img_1_740.jpg	img_2_64.jpg	img_3_594.jpg	img_4_539.jpg
# img_0_649.jpg	img_1_741.jpg	img_2_659.jpg	img_3_597.jpg	img_4_53.jpg
# img_0_653.jpg	img_1_742.jpg	img_2_665.jpg	img_3_5.jpg	img_4_542.jpg
# img_0_655.jpg	img_1_743.jpg	img_2_667.jpg	img_3_600.jpg	img_4_546.jpg
# img_0_656.jpg	img_1_745.jpg	img_2_669.jpg	img_3_601.jpg	img_4_547.jpg
# img_0_658.jpg	img_1_746.jpg	img_2_670.jpg	img_3_603.jpg	img_4_548.jpg
# img_0_660.jpg	img_1_749.jpg	img_2_673.jpg	img_3_606.jpg	img_4_551.jpg
# img_0_663.jpg	img_1_751.jpg	img_2_674.jpg	img_3_608.jpg	img_4_552.jpg
# img_0_667.jpg	img_1_75.jpg	img_2_675.jpg	img_3_615.jpg	img_4_553.jpg
# img_0_669.jpg	img_1_760.jpg	img_2_676.jpg	img_3_61.jpg	img_4_558.jpg
# img_0_670.jpg	img_1_761.jpg	img_2_677.jpg	img_3_624.jpg	img_4_559.jpg
# img_0_676.jpg	img_1_762.jpg	img_2_678.jpg	img_3_625.jpg	img_4_561.jpg
# img_0_677.jpg	img_1_763.jpg	img_2_67.jpg	img_3_627.jpg	img_4_567.jpg
# img_0_678.jpg	img_1_764.jpg	img_2_683.jpg	img_3_629.jpg	img_4_569.jpg
# img_0_685.jpg	img_1_766.jpg	img_2_685.jpg	img_3_631.jpg	img_4_570.jpg
# img_0_68.jpg	img_1_769.jpg	img_2_686.jpg	img_3_635.jpg	img_4_572.jpg
# img_0_691.jpg	img_1_76.jpg	img_2_687.jpg	img_3_636.jpg	img_4_575.jpg
# img_0_694.jpg	img_1_774.jpg	img_2_688.jpg	img_3_638.jpg	img_4_580.jpg
# img_0_698.jpg	img_1_776.jpg	img_2_690.jpg	img_3_639.jpg	img_4_586.jpg
# img_0_700.jpg	img_1_777.jpg	img_2_698.jpg	img_3_63.jpg	img_4_58.jpg
# img_0_703.jpg	img_1_779.jpg	img_2_699.jpg	img_3_643.jpg	img_4_590.jpg
# img_0_712.jpg	img_1_77.jpg	img_2_6.jpg	img_3_645.jpg	img_4_591.jpg
# img_0_713.jpg	img_1_781.jpg	img_2_700.jpg	img_3_648.jpg	img_4_592.jpg
# img_0_714.jpg	img_1_784.jpg	img_2_701.jpg	img_3_649.jpg	img_4_595.jpg
# img_0_717.jpg	img_1_787.jpg	img_2_704.jpg	img_3_64.jpg	img_4_597.jpg
# img_0_719.jpg	img_1_789.jpg	img_2_705.jpg	img_3_653.jpg	img_4_5.jpg
# img_0_71.jpg	img_1_78.jpg	img_2_70.jpg	img_3_654.jpg	img_4_600.jpg
# img_0_723.jpg	img_1_793.jpg	img_2_712.jpg	img_3_655.jpg	img_4_601.jpg
# img_0_736.jpg	img_1_794.jpg	img_2_717.jpg	img_3_656.jpg	img_4_602.jpg
# img_0_741.jpg	img_1_799.jpg	img_2_719.jpg	img_3_659.jpg	img_4_603.jpg
# img_0_745.jpg	img_1_801.jpg	img_2_71.jpg	img_3_65.jpg	img_4_607.jpg
# img_0_74.jpg	img_1_803.jpg	img_2_726.jpg	img_3_665.jpg	img_4_60.jpg
# img_0_754.jpg	img_1_804.jpg	img_2_727.jpg	img_3_666.jpg	img_4_611.jpg
# img_0_758.jpg	img_1_805.jpg	img_2_728.jpg	img_3_672.jpg	img_4_613.jpg
# img_0_75.jpg	img_1_806.jpg	img_2_730.jpg	img_3_673.jpg	img_4_614.jpg
# img_0_764.jpg	img_1_808.jpg	img_2_733.jpg	img_3_676.jpg	img_4_617.jpg
# img_0_767.jpg	img_1_812.jpg	img_2_734.jpg	img_3_677.jpg	img_4_618.jpg
# img_0_768.jpg	img_1_817.jpg	img_2_736.jpg	img_3_679.jpg	img_4_621.jpg
# img_0_769.jpg	img_1_822.jpg	img_2_737.jpg	img_3_67.jpg	img_4_624.jpg
# img_0_770.jpg	img_1_823.jpg	img_2_738.jpg	img_3_680.jpg	img_4_629.jpg
# img_0_773.jpg	img_1_824.jpg	img_2_739.jpg	img_3_682.jpg	img_4_62.jpg
# img_0_776.jpg	img_1_826.jpg	img_2_740.jpg	img_3_684.jpg	img_4_635.jpg
# img_0_778.jpg	img_1_827.jpg	img_2_742.jpg	img_3_692.jpg	img_4_641.jpg
# img_0_779.jpg	img_1_829.jpg	img_2_744.jpg	img_3_695.jpg	img_4_643.jpg
# img_0_782.jpg	img_1_832.jpg	img_2_745.jpg	img_3_699.jpg	img_4_649.jpg
# img_0_785.jpg	img_1_834.jpg	img_2_748.jpg	img_3_700.jpg	img_4_650.jpg
# img_0_78.jpg	img_1_835.jpg	img_2_749.jpg	img_3_703.jpg	img_4_651.jpg
# img_0_796.jpg	img_1_838.jpg	img_2_750.jpg	img_3_707.jpg	img_4_652.jpg
# img_0_798.jpg	img_1_83.jpg	img_2_751.jpg	img_3_70.jpg	img_4_656.jpg
# img_0_7.jpg	img_1_841.jpg	img_2_756.jpg	img_3_716.jpg	img_4_657.jpg
# img_0_802.jpg	img_1_842.jpg	img_2_758.jpg	img_3_719.jpg	img_4_659.jpg
# img_0_805.jpg	img_1_843.jpg	img_2_759.jpg	img_3_721.jpg	img_4_663.jpg
# img_0_808.jpg	img_1_844.jpg	img_2_75.jpg	img_3_723.jpg	img_4_666.jpg
# img_0_810.jpg	img_1_846.jpg	img_2_761.jpg	img_3_733.jpg	img_4_670.jpg
# img_0_811.jpg	img_1_850.jpg	img_2_763.jpg	img_3_734.jpg	img_4_677.jpg
# img_0_815.jpg	img_1_851.jpg	img_2_769.jpg	img_3_736.jpg	img_4_678.jpg
# img_0_819.jpg	img_1_852.jpg	img_2_76.jpg	img_3_738.jpg	img_4_679.jpg
# img_0_81.jpg	img_1_855.jpg	img_2_772.jpg	img_3_739.jpg	img_4_680.jpg
# img_0_820.jpg	img_1_859.jpg	img_2_773.jpg	img_3_740.jpg	img_4_683.jpg
# img_0_823.jpg	img_1_85.jpg	img_2_775.jpg	img_3_741.jpg	img_4_684.jpg
# img_0_825.jpg	img_1_860.jpg	img_2_776.jpg	img_3_742.jpg	img_4_688.jpg
# img_0_826.jpg	img_1_862.jpg	img_2_779.jpg	img_3_744.jpg	img_4_68.jpg
# img_0_828.jpg	img_1_863.jpg	img_2_781.jpg	img_3_745.jpg	img_4_690.jpg
# img_0_82.jpg	img_1_868.jpg	img_2_782.jpg	img_3_748.jpg	img_4_699.jpg
# img_0_830.jpg	img_1_870.jpg	img_2_786.jpg	img_3_74.jpg	img_4_700.jpg
# img_0_834.jpg	img_1_874.jpg	img_2_788.jpg	img_3_750.jpg	img_4_703.jpg
# img_0_836.jpg	img_1_876.jpg	img_2_795.jpg	img_3_754.jpg	img_4_706.jpg
# img_0_837.jpg	img_1_877.jpg	img_2_797.jpg	img_3_75.jpg	img_4_707.jpg
# img_0_83.jpg	img_1_878.jpg	img_2_798.jpg	img_3_764.jpg	img_4_708.jpg
# img_0_840.jpg	img_1_87.jpg	img_2_800.jpg	img_3_766.jpg	img_4_70.jpg
# img_0_841.jpg	img_1_880.jpg	img_2_803.jpg	img_3_767.jpg	img_4_711.jpg
# img_0_847.jpg	img_1_884.jpg	img_2_806.jpg	img_3_768.jpg	img_4_712.jpg
# img_0_848.jpg	img_1_886.jpg	img_2_80.jpg	img_3_771.jpg	img_4_715.jpg
# img_0_854.jpg	img_1_889.jpg	img_2_813.jpg	img_3_777.jpg	img_4_717.jpg
# img_0_857.jpg	img_1_88.jpg	img_2_816.jpg	img_3_77.jpg	img_4_718.jpg
# img_0_859.jpg	img_1_890.jpg	img_2_817.jpg	img_3_781.jpg	img_4_720.jpg
# img_0_862.jpg	img_1_898.jpg	img_2_818.jpg	img_3_783.jpg	img_4_724.jpg
# img_0_875.jpg	img_1_899.jpg	img_2_81.jpg	img_3_785.jpg	img_4_726.jpg
# img_0_878.jpg	img_1_89.jpg	img_2_820.jpg	img_3_787.jpg	img_4_727.jpg
# img_0_883.jpg	img_1_8.jpg	img_2_823.jpg	img_3_791.jpg	img_4_728.jpg
# img_0_884.jpg	img_1_900.jpg	img_2_825.jpg	img_3_792.jpg	img_4_729.jpg
# img_0_885.jpg	img_1_906.jpg	img_2_826.jpg	img_3_793.jpg	img_4_730.jpg
# img_0_886.jpg	img_1_911.jpg	img_2_828.jpg	img_3_794.jpg	img_4_739.jpg
# img_0_891.jpg	img_1_915.jpg	img_2_831.jpg	img_3_798.jpg	img_4_73.jpg
# img_0_895.jpg	img_1_917.jpg	img_2_833.jpg	img_3_79.jpg	img_4_740.jpg
# img_0_898.jpg	img_1_91.jpg	img_2_834.jpg	img_3_7.jpg	img_4_742.jpg
# img_0_8.jpg	img_1_921.jpg	img_2_835.jpg	img_3_809.jpg	img_4_743.jpg
# img_0_903.jpg	img_1_922.jpg	img_2_837.jpg	img_3_810.jpg	img_4_744.jpg
# img_0_904.jpg	img_1_923.jpg	img_2_83.jpg	img_3_811.jpg	img_4_745.jpg
# img_0_908.jpg	img_1_924.jpg	img_2_841.jpg	img_3_812.jpg	img_4_747.jpg
# img_0_909.jpg	img_1_927.jpg	img_2_843.jpg	img_3_816.jpg	img_4_749.jpg
# img_0_910.jpg	img_1_929.jpg	img_2_847.jpg	img_3_81.jpg	img_4_756.jpg
# img_0_913.jpg	img_1_930.jpg	img_2_848.jpg	img_3_821.jpg	img_4_757.jpg
# img_0_914.jpg	img_1_933.jpg	img_2_850.jpg	img_3_823.jpg	img_4_758.jpg
# img_0_915.jpg	img_1_935.jpg	img_2_854.jpg	img_3_826.jpg	img_4_75.jpg
# img_0_919.jpg	img_1_937.jpg	img_2_856.jpg	img_3_827.jpg	img_4_761.jpg
# img_0_91.jpg	img_1_938.jpg	img_2_859.jpg	img_3_836.jpg	img_4_762.jpg
# img_0_920.jpg	img_1_939.jpg	img_2_85.jpg	img_3_837.jpg	img_4_763.jpg
# img_0_926.jpg	img_1_93.jpg	img_2_860.jpg	img_3_844.jpg	img_4_765.jpg
# img_0_927.jpg	img_1_940.jpg	img_2_864.jpg	img_3_845.jpg	img_4_766.jpg
# img_0_92.jpg	img_1_941.jpg	img_2_866.jpg	img_3_846.jpg	img_4_768.jpg
# img_0_930.jpg	img_1_942.jpg	img_2_868.jpg	img_3_847.jpg	img_4_769.jpg
# img_0_932.jpg	img_1_943.jpg	img_2_870.jpg	img_3_849.jpg	img_4_770.jpg
# img_0_935.jpg	img_1_945.jpg	img_2_873.jpg	img_3_852.jpg	img_4_77.jpg
# img_0_936.jpg	img_1_947.jpg	img_2_879.jpg	img_3_858.jpg	img_4_781.jpg
# img_0_937.jpg	img_1_948.jpg	img_2_881.jpg	img_3_862.jpg	img_4_784.jpg
# img_0_938.jpg	img_1_950.jpg	img_2_885.jpg	img_3_863.jpg	img_4_785.jpg
# img_0_93.jpg	img_1_952.jpg	img_2_894.jpg	img_3_871.jpg	img_4_786.jpg
# img_0_943.jpg	img_1_954.jpg	img_2_895.jpg	img_3_876.jpg	img_4_78.jpg
# img_0_944.jpg	img_1_955.jpg	img_2_896.jpg	img_3_878.jpg	img_4_790.jpg
# img_0_947.jpg	img_1_957.jpg	img_2_89.jpg	img_3_87.jpg	img_4_792.jpg
# img_0_951.jpg	img_1_958.jpg	img_2_900.jpg	img_3_881.jpg	img_4_793.jpg
# img_0_952.jpg	img_1_962.jpg	img_2_901.jpg	img_3_882.jpg	img_4_796.jpg
# img_0_953.jpg	img_1_964.jpg	img_2_903.jpg	img_3_884.jpg	img_4_797.jpg
# img_0_954.jpg	img_1_969.jpg	img_2_904.jpg	img_3_888.jpg	img_4_799.jpg
# img_0_957.jpg	img_1_970.jpg	img_2_906.jpg	img_3_88.jpg	img_4_7.jpg
# img_0_959.jpg	img_1_975.jpg	img_2_907.jpg	img_3_891.jpg	img_4_805.jpg
# img_0_95.jpg	img_1_977.jpg	img_2_90.jpg	img_3_892.jpg	img_4_808.jpg
# img_0_960.jpg	img_1_978.jpg	img_2_911.jpg	img_3_894.jpg	img_4_809.jpg
# img_0_964.jpg	img_1_980.jpg	img_2_912.jpg	img_3_895.jpg	img_4_810.jpg
# img_0_965.jpg	img_1_981.jpg	img_2_913.jpg	img_3_896.jpg	img_4_811.jpg
# img_0_974.jpg	img_1_982.jpg	img_2_914.jpg	img_3_904.jpg	img_4_812.jpg
# img_0_977.jpg	img_1_983.jpg	img_2_915.jpg	img_3_907.jpg	img_4_816.jpg
# img_0_97.jpg	img_1_984.jpg	img_2_916.jpg	img_3_908.jpg	img_4_817.jpg
# img_0_982.jpg	img_1_98.jpg	img_2_917.jpg	img_3_910.jpg	img_4_818.jpg
# img_0_988.jpg	img_1_992.jpg	img_2_919.jpg	img_3_911.jpg	img_4_81.jpg
# img_0_991.jpg	img_1_993.jpg	img_2_91.jpg	img_3_913.jpg	img_4_820.jpg
# img_0_992.jpg	img_1_997.jpg	img_2_921.jpg	img_3_915.jpg	img_4_822.jpg
# img_0_996.jpg	img_1_998.jpg	img_2_924.jpg	img_3_918.jpg	img_4_824.jpg
# img_0_998.jpg	img_1_99.jpg	img_2_925.jpg	img_3_919.jpg	img_4_828.jpg
# img_0_9.jpg	img_2_0.jpg	img_2_926.jpg	img_3_920.jpg	img_4_833.jpg
# img_1_0.jpg	img_2_1001.jpg	img_2_929.jpg	img_3_921.jpg	img_4_834.jpg
# img_1_1000.jpg	img_2_100.jpg	img_2_92.jpg	img_3_922.jpg	img_4_840.jpg
# img_1_1001.jpg	img_2_1011.jpg	img_2_931.jpg	img_3_923.jpg	img_4_844.jpg
# img_1_1004.jpg	img_2_1015.jpg	img_2_933.jpg	img_3_925.jpg	img_4_845.jpg
# img_1_101.jpg	img_2_1017.jpg	img_2_934.jpg	img_3_933.jpg	img_4_846.jpg
# img_1_1020.jpg	img_2_1018.jpg	img_2_935.jpg	img_3_935.jpg	img_4_84.jpg
# img_1_1021.jpg	img_2_1022.jpg	img_2_936.jpg	img_3_943.jpg	img_4_851.jpg
# img_1_1023.jpg	img_2_1025.jpg	img_2_937.jpg	img_3_944.jpg	img_4_856.jpg
# img_1_1025.jpg	img_2_1026.jpg	img_2_941.jpg	img_3_945.jpg	img_4_862.jpg
# img_1_1028.jpg	img_2_102.jpg	img_2_946.jpg	img_3_94.jpg	img_4_863.jpg
# img_1_1030.jpg	img_2_1031.jpg	img_2_950.jpg	img_3_951.jpg	img_4_866.jpg
# img_1_1031.jpg	img_2_1032.jpg	img_2_952.jpg	img_3_952.jpg	img_4_867.jpg
# img_1_1032.jpg	img_2_1033.jpg	img_2_953.jpg	img_3_954.jpg	img_4_868.jpg
# img_1_1034.jpg	img_2_1034.jpg	img_2_954.jpg	img_3_957.jpg	img_4_869.jpg
# img_1_1036.jpg	img_2_1035.jpg	img_2_958.jpg	img_3_95.jpg	img_4_86.jpg
# img_1_1037.jpg	img_2_103.jpg	img_2_95.jpg	img_3_962.jpg	img_4_872.jpg
# img_1_1038.jpg	img_2_1040.jpg	img_2_960.jpg	img_3_963.jpg	img_4_875.jpg
# img_1_1040.jpg	img_2_1041.jpg	img_2_964.jpg	img_3_964.jpg	img_4_876.jpg
# img_1_1043.jpg	img_2_1042.jpg	img_2_965.jpg	img_3_967.jpg	img_4_879.jpg
# img_1_1044.jpg	img_2_1043.jpg	img_2_967.jpg	img_3_96.jpg	img_4_87.jpg
# img_1_106.jpg	img_2_1045.jpg	img_2_969.jpg	img_3_970.jpg	img_4_884.jpg
# img_1_107.jpg	img_2_104.jpg	img_2_970.jpg	img_3_972.jpg	img_4_885.jpg
# img_1_109.jpg	img_2_1050.jpg	img_2_973.jpg	img_3_977.jpg	img_4_886.jpg
# img_1_113.jpg	img_2_1051.jpg	img_2_975.jpg	img_3_986.jpg	img_4_887.jpg
# img_1_116.jpg	img_2_1054.jpg	img_2_977.jpg	img_3_98.jpg	img_4_888.jpg
# img_1_117.jpg	img_2_1058.jpg	img_2_978.jpg	img_3_990.jpg	img_4_892.jpg
# img_1_119.jpg	img_2_105.jpg	img_2_979.jpg	img_3_991.jpg	img_4_893.jpg
# img_1_11.jpg	img_2_106.jpg	img_2_97.jpg	img_3_997.jpg	img_4_894.jpg
# img_1_120.jpg	img_2_1073.jpg	img_2_980.jpg	img_3_99.jpg	img_4_895.jpg
# img_1_126.jpg	img_2_1074.jpg	img_2_981.jpg	img_4_1000.jpg	img_4_897.jpg
# img_1_127.jpg	img_2_1075.jpg	img_2_985.jpg	img_4_1002.jpg	img_4_898.jpg
# img_1_128.jpg	img_2_1076.jpg	img_2_986.jpg	img_4_1004.jpg	img_4_89.jpg
# img_1_129.jpg	img_2_1077.jpg	img_2_993.jpg	img_4_1005.jpg	img_4_905.jpg
# img_1_12.jpg	img_2_107.jpg	img_2_994.jpg	img_4_1009.jpg	img_4_908.jpg
# img_1_130.jpg	img_2_1083.jpg	img_2_999.jpg	img_4_100.jpg	img_4_909.jpg
# img_1_133.jpg	img_2_1088.jpg	img_2_99.jpg	img_4_1010.jpg	img_4_913.jpg
# img_1_136.jpg	img_2_1089.jpg	img_2_9.jpg	img_4_101.jpg	img_4_914.jpg
# img_1_140.jpg	img_2_1090.jpg	img_3_0.jpg	img_4_1022.jpg	img_4_915.jpg
# img_1_146.jpg	img_2_1092.jpg	img_3_1003.jpg	img_4_1023.jpg	img_4_917.jpg
# img_1_147.jpg	img_2_1095.jpg	img_3_1004.jpg	img_4_1027.jpg	img_4_91.jpg
# img_1_148.jpg	img_2_1096.jpg	img_3_1007.jpg	img_4_1028.jpg	img_4_920.jpg
# img_1_151.jpg	img_2_1099.jpg	img_3_1008.jpg	img_4_102.jpg	img_4_924.jpg
# img_1_155.jpg	img_2_10.jpg	img_3_1009.jpg	img_4_1032.jpg	img_4_928.jpg
# img_1_156.jpg	img_2_1101.jpg	img_3_100.jpg	img_4_1034.jpg	img_4_938.jpg
# img_1_162.jpg	img_2_1103.jpg	img_3_1015.jpg	img_4_1037.jpg	img_4_939.jpg
# img_1_165.jpg	img_2_1104.jpg	img_3_1018.jpg	img_4_1038.jpg	img_4_941.jpg
# img_1_167.jpg	img_2_1105.jpg	img_3_1019.jpg	img_4_1039.jpg	img_4_945.jpg
# img_1_168.jpg	img_2_1107.jpg	img_3_1020.jpg	img_4_1047.jpg	img_4_946.jpg
# img_1_169.jpg	img_2_1108.jpg	img_3_1025.jpg	img_4_1051.jpg	img_4_947.jpg
# img_1_171.jpg	img_2_1109.jpg	img_3_1026.jpg	img_4_1052.jpg	img_4_949.jpg
# img_1_172.jpg	img_2_1111.jpg	img_3_102.jpg	img_4_1054.jpg	img_4_94.jpg
# img_1_173.jpg	img_2_1113.jpg	img_3_1034.jpg	img_4_1061.jpg	img_4_952.jpg
# img_1_174.jpg	img_2_1114.jpg	img_3_1037.jpg	img_4_1062.jpg	img_4_954.jpg
# img_1_177.jpg	img_2_1116.jpg	img_3_1038.jpg	img_4_1065.jpg	img_4_955.jpg
# img_1_178.jpg	img_2_1117.jpg	img_3_103.jpg	img_4_1067.jpg	img_4_957.jpg
# img_1_179.jpg	img_2_1119.jpg	img_3_1040.jpg	img_4_1068.jpg	img_4_959.jpg
# img_1_180.jpg	img_2_111.jpg	img_3_1041.jpg	img_4_106.jpg	img_4_963.jpg
# img_1_181.jpg	img_2_1120.jpg	img_3_1043.jpg	img_4_1070.jpg	img_4_966.jpg
# img_1_183.jpg	img_2_1121.jpg	img_3_1045.jpg	img_4_1072.jpg	img_4_968.jpg
# img_1_186.jpg	img_2_1122.jpg	img_3_1049.jpg	img_4_1076.jpg	img_4_976.jpg
# img_1_187.jpg	img_2_1123.jpg	img_3_1051.jpg	img_4_1078.jpg	img_4_97.jpg
# img_1_188.jpg	img_2_112.jpg	img_3_1056.jpg	img_4_1081.jpg	img_4_980.jpg
# img_1_18.jpg	img_2_113.jpg	img_3_1057.jpg	img_4_1087.jpg	img_4_984.jpg
# img_1_193.jpg	img_2_117.jpg	img_3_1058.jpg	img_4_1091.jpg	img_4_98.jpg
# img_1_197.jpg	img_2_119.jpg	img_3_1062.jpg	img_4_1092.jpg	img_4_990.jpg
# img_1_198.jpg	img_2_120.jpg	img_3_1065.jpg	img_4_1093.jpg	img_4_995.jpg
# img_1_200.jpg	img_2_129.jpg	img_3_1067.jpg	img_4_1095.jpg	img_4_998.jpg
# img_1_204.jpg	img_2_131.jpg	img_3_1069.jpg	img_4_1099.jpg	img_4_999.jpg
# img_1_206.jpg	img_2_132.jpg	img_3_1070.jpg	img_4_109.jpg	img_4_9.jpg
# img_1_207.jpg	img_2_136.jpg	img_3_1072.jpg	img_4_10.jpg

# %%
# Define paths to train and test directories
train_dir = DATA_PATH / "train"
test_dir = DATA_PATH / "test"

# Count images in each directory
def count_images(directory):
    counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            counts[class_name] = len(os.listdir(class_path))
    return counts

print("Image distribution:")
print(f"Training set: {count_images(train_dir)}")
print(f"Testing set:  {count_images(test_dir)}")

# Visualize some sample images
print("\nVisualizing sample images from the training set:")

# Use torchvision's ImageFolder to easily load data
temp_dataset = datasets.ImageFolder(train_dir)
class_names = temp_dataset.classes

plt.figure(figsize=(10, 5))
for i in range(8):
    # Get a random image
    idx = np.random.randint(0, len(temp_dataset))
    image, label_idx = temp_dataset[idx]
    label_name = class_names[label_idx]

    # Plot
    plt.subplot(2, 4, i + 1)
    plt.imshow(image)
    plt.title(f"{label_name}\n(Class {label_idx})")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Image distribution:
# Training set: {'muffin': 2174, 'chihuahua': 2559}
# Testing set:  {'muffin': 544, 'chihuahua': 640}
#
# Visualizing sample images from the training set:

# %% [markdown]
# # Data Preprocessing
#
# > Prepared the images for the model.
# <br> We defined distinct transformation pipelines for our data:
# <br>one for training that included data augmentation (random cropping and flipping) to help the model generalize, and another for validation and testing with standard resizing and normalization.
# <br>We then split our original training data into a training set and a validation set (85/15 split) and wrapped all three datasets (train, validation, test) in PyTorch DataLoaders to efficiently feed them to the model in batches.

# %%
from torchvision import transforms

# InceptionV3 expects input images of size 299x299
IMG_SIZE = 299

# Define the normalization transform using ImageNet stats
# Standard values for models pretrained on ImageNet
imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std = [0.229, 0.224, 0.225]

# Transform pipeline for the training data with augmentation
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(IMG_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=imagenet_mean, std=imagenet_std)
])

# Transform pipeline for validation and testing data (no augmentation)
# Resize and CenterCrop to get a consistent 299x299 view
val_test_transform = transforms.Compose([
    transforms.Resize(IMG_SIZE + 1),
    transforms.CenterCrop(IMG_SIZE),
    transforms.ToTensor(),
    transforms.Normalize(mean=imagenet_mean, std=imagenet_std)
])

print("Image transformations defined successfully.")
print(f"Input image size set to: {IMG_SIZE}x{IMG_SIZE}")
# Out:
# Image transformations defined successfully.
# Input image size set to: 299x299

# %%
from torch.utils.data import DataLoader, random_split

train_dir = DATA_PATH / "train"
test_dir = DATA_PATH / "test"

# Load the full training dataset (without transforms)
full_train_dataset_no_transform = datasets.ImageFolder(train_dir)
class_names = full_train_dataset_no_transform.classes
print(f"Class names: {class_names}")
print(f"Class to index mapping: {full_train_dataset_no_transform.class_to_idx}")


# Split size (85% training, 15% validation)
val_split = 0.15
val_size = int(val_split * len(full_train_dataset_no_transform))
train_size = len(full_train_dataset_no_transform) - val_size

generator = torch.Generator().manual_seed(42)
train_subset, val_subset = random_split(
    full_train_dataset_no_transform,
    [train_size, val_size],
    generator=generator
)

train_subset.dataset.transform = train_transform
val_subset.dataset.transform = val_test_transform

# Test dataset with the transform
test_dataset = datasets.ImageFolder(test_dir, transform=val_test_transform)


print(f"\nFull training data count: {len(full_train_dataset_no_transform)}")
print(f"Splitting into:")
print(f" -> Training subset:   {len(train_subset)} samples")
print(f" -> Validation subset: {len(val_subset)} samples")
print(f"Test data count:         {len(test_dataset)} samples")
# Out:
# Class names: ['chihuahua', 'muffin']
# Class to index mapping: {'chihuahua': 0, 'muffin': 1}
#
# Full training data count: 4733
# Splitting into:
#  -> Training subset:   4024 samples
#  -> Validation subset: 709 samples
# Test data count:         1184 samples

# %%
import torchvision

BATCH_SIZE = 32

# Create DataLoaders
train_dataloader = DataLoader(
    dataset=train_subset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=os.cpu_count()
)

val_dataloader = DataLoader(
    dataset=val_subset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=os.cpu_count()
)

test_dataloader = DataLoader(
    dataset=test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=os.cpu_count()
)

print(f"DataLoaders created with batch size: {BATCH_SIZE}")

# Visualizing batch
print("\nVisualizing one batch of training data...")

def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array(imagenet_mean)
    std = np.array(imagenet_std)
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title, wrap=True)
    plt.pause(0.001)

inputs, classes = next(iter(train_dataloader))

out = torchvision.utils.make_grid(inputs, nrow=8)

plt.figure(figsize=(15, 10))
class_titles = [class_names[x] for x in classes]
imshow(out, title=f"Sample Batch\n{class_titles}")
# Out:
# DataLoaders created with batch size: 32
#
# Visualizing one batch of training data...

# %% [markdown]
# # Model Architecture
#
# > We built our classifier using transfer learning.
# <br>We loaded a pre-trained InceptionV3 model with weights learned from ImageNet.
# <br>We "froze" all the existing layers to use them as a fixed feature extractor.
# <br>We then replaced the model's final classification layer with a new one designed for our binary task (2 outputs).
# <br><br>Then lastly, we defined our loss function (CrossEntropyLoss) and the Adam optimizer, instructing it to only train the parameters of our new, unfrozen classification layer.

# %%
from torchvision import models

# Pretrained InceptionV3 model
# Using the latest recommended weights
weights = models.Inception_V3_Weights.IMAGENET1K_V1
model = models.inception_v3(weights=weights)
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00, 203MB/s]

# %%
# Freeze all the parameters in the pre-trained model
for param in model.parameters():
    param.requires_grad = False

print("All pre-trained layers have been frozen.")
# Out:
# All pre-trained layers have been frozen.

# %%
import torch.nn as nn

num_ftrs = model.fc.in_features
print(f"Number of input features for the final layer: {num_ftrs}")

model.fc = nn.Linear(num_ftrs, len(class_names))

print("\nModel's final layer before modification:")
print("... (original model.fc): Linear(in_features=2048, out_features=1000, bias=True)")

print("\nModel's final layer after modification:")
print(model.fc)

if hasattr(model, 'AuxLogits') and model.AuxLogits is not None:
    num_ftrs_aux = model.AuxLogits.fc.in_features
    model.AuxLogits.fc = nn.Linear(num_ftrs_aux, len(class_names))
    print("\nAuxiliary classifier layer also modified.")
# Out:
# Number of input features for the final layer: 2048
#
# Model's final layer before modification:
# ... (original model.fc): Linear(in_features=2048, out_features=1000, bias=True)
#
# Model's final layer after modification:
# Linear(in_features=2048, out_features=2, bias=True)
#
# Auxiliary classifier layer also modified.

# %%
import torch.optim as optim

model = model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss()

# Define the optimizer
# We pass only the parameters that should be updated to the optimizer.
# These are the parameters of the new `fc` layers we created. (can be seen on the printed model architecture at the very end of this notebook)
params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad:
        params_to_update.append(param)
        print(f" -> Will train parameter: {name}")

optimizer = optim.Adam(params_to_update, lr=0.001)

print(f"\nModel moved to device: {device}")
print(f"Loss function: {criterion}")
print(f"Optimizer: Adam with learning rate 0.001")
# Out:
#  -> Will train parameter: AuxLogits.fc.weight
#  -> Will train parameter: AuxLogits.fc.bias
#  -> Will train parameter: fc.weight
#  -> Will train parameter: fc.bias
#
# Model moved to device: cuda
# Loss function: CrossEntropyLoss()
# Optimizer: Adam with learning rate 0.001

# %% [markdown]
# # Phase 4: Training Setup (Feature Extraction)
#
#
# > Initial model training. We created a training loop function that handled both training and validation steps, calculated accuracy and loss, and updated the model's weights. This function implemented checkpointing to save the model with the best validation accuracy and early stopping to halt training if performance stopped improving.

# %%
import time
import copy

def train_model(model, criterion, optimizer, train_dataloader, val_dataloader,
                num_epochs=10, patience=3, model_save_path='best_model.pth'):

    start_time = time.time()

    # Variables for tracking best performance and early stopping
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    epochs_no_improve = 0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
                dataloader = train_dataloader
            else:
                model.eval()   # Set model to evaluate mode
                dataloader = val_dataloader

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward pass
                # Track history only in train
                with torch.set_grad_enabled(phase == 'train'):
                    if phase == 'train' and isinstance(model, models.Inception3):
                        outputs, aux_outputs = model(inputs)
                        loss1 = criterion(outputs, labels)
                        loss2 = criterion(aux_outputs, labels)
                        loss = loss1 + 0.4 * loss2 # As recommended in the InceptionV3 paper
                    else:
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)

                    _, preds = torch.max(outputs, 1)

                    # Backward pass + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloader.dataset)
            epoch_acc = running_corrects.double() / len(dataloader.dataset)

            # Store history
            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc.item())

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Deep copy the model if it's the best one so far
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(model.state_dict(), model_save_path)
                epochs_no_improve = 0
            elif phase == 'val':
                epochs_no_improve += 1

        # Early stopping check
        if epochs_no_improve >= patience:
            print(f'\nEarly stopping triggered after {patience} epochs with no improvement.')
            break

        print()

    time_elapsed = time.time() - start_time
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:.4f}')

    # Load best model weights
    model.load_state_dict(best_model_wts)
    return model, history

print("Training function `train_model` is defined.")
# Out:
# Training function `train_model` is defined.

# %%
NUM_EPOCHS = 15
PATIENCE = 3
MODEL_SAVE_PATH = "inception_v3_muffin_chihuahua_best.pth"

model, history = train_model(
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    train_dataloader=train_dataloader,
    val_dataloader=val_dataloader,
    num_epochs=NUM_EPOCHS,
    patience=PATIENCE,
    model_save_path=MODEL_SAVE_PATH
)
# Out:
# Epoch 1/15
# ----------
# Train Loss: 0.2317 Acc: 0.9386
# Val Loss: 0.0707 Acc: 0.9929
# ✨ Validation accuracy improved! Saving model to inception_v3_muffin_chihuahua_best.pth
#
# Epoch 2/15
# ----------
# Train Loss: 0.1057 Acc: 0.9729
# Val Loss: 0.0499 Acc: 0.9901
#
# Epoch 3/15
# ----------
# Train Loss: 0.0852 Acc: 0.9784
# Val Loss: 0.0447 Acc: 0.9915
#
# Epoch 4/15
# ----------
# Train Loss: 0.0952 Acc: 0.9727
# Val Loss: 0.0381 Acc: 0.9901
#
# Early stopping triggered after 3 epochs with no improvement.
# Training complete in 4m 8s
# Best val Acc: 0.9929

# %%
# Plot the training and validation accuracy and loss
train_acc = [h for h in history['train_acc']]
val_acc = [h for h in history['val_acc']]
train_loss = history['train_loss']
val_loss = history['val_loss']

epochs_ran = range(1, len(train_acc) + 1)

plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_ran, train_acc, 'b-o', label='Training Accuracy')
plt.plot(epochs_ran, val_acc, 'r-o', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_ran, train_loss, 'b-o', label='Training Loss')
plt.plot(epochs_ran, val_loss, 'r-o', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Phase 5: Fine-tuning
#
# > To potentially improve performance further, we performed fine-tuning. We took our best model from the previous phase and unfroze all of its layers, making the entire network trainable. We then created a new optimizer with a very low learning rate to make subtle adjustments to the powerful pre-trained weights without destroying them. Running the training loop again with this setup allowed the deeper layers to adapt slightly to our specific dataset (this pushed the model's validation accuracy to a perfect 100%.)

# %%
model.load_state_dict(torch.load(MODEL_SAVE_PATH))

# Unfreeze all model parameters
for param in model.parameters():
    param.requires_grad = True

print("All model layers have been unfrozen and are now trainable.")
# Out:
# All model layers have been unfrozen and are now trainable.

# %%
# lower learning rate for fine-tuning
fine_tune_optimizer = optim.Adam(model.parameters(), lr=0.0001)

print("New optimizer created for fine-tuning with a lower learning rate (lr=0.0001).")
print("All model parameters are now included in the optimizer.")
# Out:
# New optimizer created for fine-tuning with a lower learning rate (lr=0.0001).
# All model parameters are now included in the optimizer.

# %%
# New save path for the fine-tuned model
FINETUNED_MODEL_SAVE_PATH = "inception_v3_finetuned_best.pth"

# Training again for 10 epoch with early stopping
print("\nStarting fine-tuning...")
model_finetuned, history_finetuned = train_model(
    model=model,
    criterion=criterion,
    optimizer=fine_tune_optimizer,
    train_dataloader=train_dataloader,
    val_dataloader=val_dataloader,
    num_epochs=10,
    patience=3,
    model_save_path=FINETUNED_MODEL_SAVE_PATH
)
# Out:
# Starting fine-tuning...
# Epoch 1/10
# ----------
# Train Loss: 0.0584 Acc: 0.9863
# Val Loss: 0.0028 Acc: 1.0000
# ✨ Validation accuracy improved! Saving model to inception_v3_finetuned_best.pth
#
# Epoch 2/10
# ----------
# Train Loss: 0.0141 Acc: 0.9968
# Val Loss: 0.0015 Acc: 1.0000
#
# Epoch 3/10
# ----------
# Train Loss: 0.0018 Acc: 1.0000
# Val Loss: 0.0002 Acc: 1.0000
#
# Epoch 4/10
# ----------
# Train Loss: 0.0038 Acc: 0.9993
# Val Loss: 0.0016 Acc: 1.0000
#
# Early stopping triggered after 3 epochs with no improvement.
# Training complete in 4m 58s
# Best val Acc: 1.0000

# %%
# After fine-tuning
train_acc = [h for h in history_finetuned['train_acc']]
val_acc = [h for h in history_finetuned['val_acc']]
train_loss = history_finetuned['train_loss']
val_loss = history_finetuned['val_loss']

epochs_ran = range(1, len(train_acc) + 1)

plt.figure(figsize=(12, 5))

# Plot Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_ran, train_acc, 'b-o', label='Training Accuracy')
plt.plot(epochs_ran, val_acc, 'r-o', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_ran, train_loss, 'b-o', label='Training Loss')
plt.plot(epochs_ran, val_loss, 'r-o', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluation & Visualization
#
# > We loaded our best fine-tuned model and generated predictions for all test images. We then calculated detailed metrics using a classification_report (precision, recall, F1-score) and visualized the results with a confusion_matrix to see the exact breakdown of correct versus incorrect predictions.

# %%
from tqdm.auto import tqdm

# Load the best fine-tuned model
model_finetuned.load_state_dict(torch.load(FINETUNED_MODEL_SAVE_PATH))

model_finetuned.to(device)
model_finetuned.eval()

# Lists to store predictions and true labels
all_preds = []
all_labels = []

print("Making predictions on the test set...")

with torch.no_grad():
    for inputs, labels in tqdm(test_dataloader, desc="Test Batches"):
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model_finetuned(inputs)
        _, preds = torch.max(outputs, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

print("\nPrediction complete.")
# Out:
# Making predictions on the test set...
# Test Batches:   0%|          | 0/37 [00:00<?, ?it/s]
# Prediction complete.

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

y_true = np.array(all_labels)
y_pred = np.array(all_preds)

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    chihuahua       1.00      1.00      1.00       640
#       muffin       1.00      1.00      1.00       544
#
#     accuracy                           1.00      1184
#    macro avg       1.00      1.00      1.00      1184
# weighted avg       1.00      1.00      1.00      1184

# %% [markdown]
# Correctly classified as 'chihuahua' (True Negative) 638<br>
# 'chihuahua' misclassified as 'muffin' (False Positive) 2<br>
# 'muffin' misclassified as 'chihuahua' (False Negative) 0<br>
# Correctly classified as 'muffin' (True Positive) 544

# %%
import random

class_to_idx = test_dataset.class_to_idx
chihuahua_idx = class_to_idx['chihuahua']
muffin_idx = class_to_idx['muffin']

# Get the indices of all images for each class in the test set
targets = np.array(test_dataset.targets)
chihuahua_indices = np.where(targets == chihuahua_idx)[0]
muffin_indices = np.where(targets == muffin_idx)[0]

# Randomly sample 8 indices from each class
num_samples_per_class = 8
random_chihuahua_indices = random.sample(list(chihuahua_indices), num_samples_per_class)
random_muffin_indices = random.sample(list(muffin_indices), num_samples_per_class)

# Combine the indices and shuffle them for a mixed display
selected_indices = random_chihuahua_indices + random_muffin_indices
random.shuffle(selected_indices)

# Retrieve the images and labels for the selected indices
images_to_show = []
labels_to_show = []
for idx in selected_indices:
    # The dataset object automatically applies the transform when we access an item
    image, label = test_dataset[idx]
    images_to_show.append(image)
    labels_to_show.append(label)

# Stack the list of tensors into a single batch tensor
image_batch = torch.stack(images_to_show)
label_batch = torch.tensor(labels_to_show)

# --- Get model predictions for our custom batch ---
with torch.no_grad():
    model_finetuned.to(device)
    image_batch_device = image_batch.to(device)
    outputs = model_finetuned(image_batch_device)
    _, preds = torch.max(outputs, 1)
    preds = preds.cpu()

# --- Plot the images with their predicted and true labels ---
plt.figure(figsize=(15, 12))
for i in range(len(selected_indices)): # Loop through our 16 selected images
    ax = plt.subplot(4, 4, i + 1)

    # Un-normalize and display the image
    img = image_batch[i].numpy().transpose((1, 2, 0))
    mean = np.array(imagenet_mean)
    std = np.array(imagenet_std)
    img = std * img + mean
    img = np.clip(img, 0, 1)
    plt.imshow(img)

    pred_label = class_names[preds[i]]
    true_label = class_names[label_batch[i]]

    # Set title color to green for correct predictions, red for incorrect
    color = "green" if pred_label == true_label else "red"

    plt.title(f"Pred: {pred_label}\nTrue: {true_label}", color=color)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Architecture

# %%
print(model_finetuned)
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=2, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )
